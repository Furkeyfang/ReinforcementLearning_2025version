# %%
#Sarsa
import time
import numpy as np
import gymnasium as gym
class SarsaAgent(object):
    def __init__(self, obs_n,act_n,learning_rate=0.01,gamma=0.9,e_greedy=0.005):
        self.act_n=act_n
        self.lr=learning_rate
        self.gamma=gamma
        self.epsilon=e_greedy
        self.Q=np.zeros((obs_n,act_n))
       
    def sample(self,obs):  
        if self.epsilon > 0: self.epsilon -= 0.0000001
        if np.random.uniform(0,1)<(1.0-self.epsilon):
            action=self.predict(obs)
        else:
            action=np.random.choice(self.act_n)
        return action
   
    def predict(self,obs):
        Q_list=self.Q[obs,:]
        maxQ=np.max(Q_list)
       
        action_list=np.where(Q_list==maxQ)[0]
        action=np.random.choice(action_list)
        return action
   
    def learn(self,obs,action,reward,next_obs,next_action,done):
       
        predict_Q=self.Q[obs,action]
        if done:
            target_Q=reward
        else:
            target_Q=reward+self.gamma*self.Q[next_obs,next_action]
        self.Q[obs,action]=predict_Q+self.lr*(target_Q-predict_Q)
       
       
def run_episode(env,agent,render=False):
    total_steps=0
    total_reward=0
   
    obs=env.reset()[0]
    action=agent.sample(obs)
   
    while True:
        next_obs,reward,done,truncated,info=env.step(action)
        next_action=agent.sample(next_obs)
       
        agent.learn(obs,action,reward,next_obs,next_action,done)
       
        action=next_action
        obs=next_obs
       
        total_reward+=reward
        total_steps+=1
       
        if render:
            env.render()
       
        if done:
            break
       
    return total_reward, total_steps
   
def test_episode(env,agent):
    total_reward=0
    obs=env.reset()[0]
    #print(f"obs type: {type(obs)}, value: {obs}")
    while True:
        action=agent.predict(obs)
        next_obs,reward,done,tru,info=env.step(action)
        total_reward+=reward
        obs=next_obs
        time.sleep(0.1)
        env.render()
        if done:
            break
    return total_reward

# %%
env=gym.make("CliffWalking-v0")
agent=SarsaAgent(
    obs_n=env.observation_space.n,
    act_n=env.action_space.n,
    learning_rate=0.1,
    gamma=0.9,
    e_greedy=0.1)
is_render=False
   
for episode in range(10000):
        
    ep_reward,ep_steps=run_episode(env,agent,is_render)
    print('Episode %s: steps=%s,reward=%.lf'%(episode,ep_steps,ep_reward))
       
       # if episode%20==0:
        #    is_render=True
        #else:z
         #   is_render=False
           
           
for episode in range(10):
    total_reward=test_episode(env,agent)
    print('teset %d reward = %.lf'%(episode,total_reward))
# Out:
# Episode 0: steps=830,reward=-2216
# Episode 1: steps=294,reward=-492
# Episode 2: steps=186,reward=-285
# Episode 3: steps=430,reward=-826
# Episode 4: steps=297,reward=-594
# Episode 5: steps=120,reward=-120
# Episode 6: steps=159,reward=-159
# Episode 7: steps=148,reward=-247
# Episode 8: steps=146,reward=-146
# Episode 9: steps=71,reward=-71
# Episode 10: steps=101,reward=-200
# Episode 11: steps=147,reward=-147
# Episode 12: steps=103,reward=-202
# Episode 13: steps=89,reward=-89
# Episode 14: steps=93,reward=-93
# Episode 15: steps=162,reward=-162
# Episode 16: steps=38,reward=-38
# Episode 17: steps=186,reward=-285
# Episode 18: steps=114,reward=-114
# Episode 19: steps=40,reward=-139
# Episode 20: steps=114,reward=-114
# Episode 21: steps=44,reward=-44
# Episode 22: steps=152,reward=-251
# Episode 23: steps=90,reward=-90
# Episode 24: steps=55,reward=-154
# Episode 25: steps=123,reward=-123
# Episode 26: steps=58,reward=-58
# Episode 27: steps=77,reward=-77
# Episode 28: steps=44,reward=-44
# Episode 29: steps=116,reward=-314
# Episode 30: steps=85,reward=-85
# Episode 31: steps=53,reward=-53
# Episode 32: steps=29,reward=-29
# Episode 33: steps=73,reward=-73
# Episode 34: steps=76,reward=-76
# Episode 35: steps=41,reward=-41
# Episode 36: steps=59,reward=-59
# Episode 37: steps=70,reward=-70
# Episode 38: steps=61,reward=-61
# Episode 39: steps=55,reward=-55
# Episode 40: steps=35,reward=-35
# Episode 41: steps=89,reward=-188
# Episode 42: steps=176,reward=-473
# Episode 43: steps=48,reward=-48
# Episode 44: steps=83,reward=-182
# Episode 45: steps=81,reward=-81
# Episode 46: steps=120,reward=-219
# Episode 47: steps=59,reward=-59
# Episode 48: steps=66,reward=-66
# Episode 49: steps=42,reward=-42
# Episode 50: steps=65,reward=-65
# Episode 51: steps=79,reward=-79
# Episode 52: steps=67,reward=-67
# Episode 53: steps=65,reward=-65
# Episode 54: steps=52,reward=-52
# Episode 55: steps=160,reward=-655
# Episode 56: steps=76,reward=-76
# Episode 57: steps=92,reward=-191
# Episode 58: steps=73,reward=-172
# Episode 59: steps=41,reward=-41
# Episode 60: steps=35,reward=-35
# Episode 61: steps=121,reward=-220
# Episode 62: steps=78,reward=-177
# Episode 63: steps=56,reward=-56
# Episode 64: steps=27,reward=-27
# Episode 65: steps=65,reward=-65
# Episode 66: steps=50,reward=-50
# Episode 67: steps=44,reward=-44
# Episode 68: steps=82,reward=-82
# Episode 69: steps=43,reward=-43
# Episode 70: steps=32,reward=-131
# Episode 71: steps=36,reward=-36
# Episode 72: steps=44,reward=-44
# Episode 73: steps=35,reward=-35
# Episode 74: steps=43,reward=-43
# Episode 75: steps=71,reward=-71
# Episode 76: steps=58,reward=-58
# Episode 77: steps=46,reward=-145
# Episode 78: steps=31,reward=-31
# Episode 79: steps=72,reward=-72
# Episode 80: steps=45,reward=-45
# Episode 81: steps=42,reward=-42
# Episode 82: steps=45,reward=-45
# Episode 83: steps=39,reward=-39
# Episode 84: steps=37,reward=-37
# Episode 85: steps=33,reward=-33
# Episode 86: steps=77,reward=-176
# Episode 87: steps=28,reward=-28
# Episode 88: steps=56,reward=-56
# Episode 89: steps=34,reward=-34
# Episode 90: steps=44,reward=-143
# Episode 91: steps=30,reward=-30
# Episode 92: steps=61,reward=-61
# Episode 93: steps=28,reward=-28
# Episode 94: steps=31,reward=-31
# Episode 95: steps=28,reward=-28
# Episode 96: steps=44,reward=-44
# Episode 97: steps=42,reward=-42
# Episode 98: steps=21,reward=-21
# Episode 99: steps=44,reward=-44
# Episode 100: steps=40,reward=-40
# Episode 101: steps=27,reward=-27
# Episode 102: steps=38,reward=-38
# Episode 103: steps=41,reward=-41
# Episode 104: steps=33,reward=-33
# Episode 105: steps=33,reward=-33
# Episode 106: steps=33,reward=-33
# Episode 107: steps=28,reward=-28
# Episode 108: steps=34,reward=-34
# Episode 109: steps=39,reward=-39
# Episode 110: steps=27,reward=-27
# Episode 111: steps=31,reward=-31
# Episode 112: steps=23,reward=-23
# Episode 113: steps=26,reward=-26
# Episode 114: steps=33,reward=-33
# Episode 115: steps=29,reward=-29
# Episode 116: steps=41,reward=-140
# Episode 117: steps=21,reward=-21
# Episode 118: steps=30,reward=-30
# Episode 119: steps=34,reward=-34
# Episode 120: steps=53,reward=-152
# Episode 121: steps=26,reward=-26
# Episode 122: steps=20,reward=-20
# Episode 123: steps=45,reward=-45
# Episode 124: steps=25,reward=-25
# Episode 125: steps=29,reward=-29
# Episode 126: steps=33,reward=-33
# Episode 127: steps=17,reward=-17
# Episode 128: steps=33,reward=-33
# Episode 129: steps=21,reward=-21
# Episode 130: steps=19,reward=-19
# Episode 131: steps=43,reward=-43
# Episode 132: steps=38,reward=-38
# Episode 133: steps=37,reward=-37
# Episode 134: steps=24,reward=-24
# Episode 135: steps=27,reward=-27
# Episode 136: steps=40,reward=-40
# Episode 137: steps=37,reward=-37
# Episode 138: steps=62,reward=-161
# Episode 139: steps=28,reward=-28
# Episode 140: steps=29,reward=-29
# Episode 141: steps=34,reward=-34
# Episode 142: steps=25,reward=-25
# Episode 143: steps=21,reward=-21
# Episode 144: steps=21,reward=-21
# Episode 145: steps=33,reward=-33
# Episode 146: steps=31,reward=-31
# Episode 147: steps=47,reward=-146
# Episode 148: steps=22,reward=-22
# Episode 149: steps=23,reward=-23
# Episode 150: steps=19,reward=-19
# Episode 151: steps=23,reward=-23
# Episode 152: steps=21,reward=-21
# Episode 153: steps=28,reward=-28
# Episode 154: steps=24,reward=-24
# Episode 155: steps=37,reward=-37
# Episode 156: steps=28,reward=-28
# Episode 157: steps=34,reward=-34
# Episode 158: steps=29,reward=-29
# Episode 159: steps=23,reward=-23
# Episode 160: steps=19,reward=-19
# Episode 161: steps=33,reward=-33
# Episode 162: steps=25,reward=-25
# Episode 163: steps=31,reward=-31
# Episode 164: steps=27,reward=-27
# Episode 165: steps=27,reward=-27
# Episode 166: steps=33,reward=-33
# Episode 167: steps=31,reward=-31
# Episode 168: steps=25,reward=-25
# Episode 169: steps=28,reward=-28
# Episode 170: steps=25,reward=-25
# Episode 171: steps=32,reward=-32
# Episode 172: steps=27,reward=-27
# Episode 173: steps=29,reward=-29
# Episode 174: steps=28,reward=-28
# Episode 175: steps=21,reward=-120
# Episode 176: steps=19,reward=-19
# Episode 177: steps=56,reward=-56
# Episode 178: steps=20,reward=-20
# Episode 179: steps=25,reward=-25
# Episode 180: steps=20,reward=-20
# Episode 181: steps=25,reward=-25
# Episode 182: steps=28,reward=-28
# Episode 183: steps=15,reward=-15
# Episode 184: steps=20,reward=-20
# Episode 185: steps=24,reward=-24
# Episode 186: steps=17,reward=-17
# Episode 187: steps=27,reward=-27
# Episode 188: steps=21,reward=-21
# Episode 189: steps=24,reward=-123
# Episode 190: steps=107,reward=-503
# Episode 191: steps=39,reward=-39
# Episode 192: steps=24,reward=-24
# Episode 193: steps=21,reward=-21
# Episode 194: steps=17,reward=-17
# Episode 195: steps=21,reward=-21
# Episode 196: steps=19,reward=-19
# Episode 197: steps=16,reward=-16
# Episode 198: steps=28,reward=-28
# Episode 199: steps=37,reward=-37
# Episode 200: steps=43,reward=-43
# Episode 201: steps=41,reward=-41
# Episode 202: steps=27,reward=-27
# Episode 203: steps=26,reward=-26
# Episode 204: steps=33,reward=-33
# Episode 205: steps=21,reward=-21
# Episode 206: steps=28,reward=-127
# Episode 207: steps=21,reward=-21
# Episode 208: steps=21,reward=-21
# Episode 209: steps=28,reward=-127
# Episode 210: steps=27,reward=-27
# Episode 211: steps=15,reward=-15
# Episode 212: steps=20,reward=-20
# Episode 213: steps=17,reward=-17
# Episode 214: steps=19,reward=-19
# Episode 215: steps=29,reward=-29
# Episode 216: steps=21,reward=-21
# Episode 217: steps=20,reward=-20
# Episode 218: steps=21,reward=-21
# Episode 219: steps=21,reward=-21
# Episode 220: steps=19,reward=-19
# Episode 221: steps=15,reward=-15
# Episode 222: steps=21,reward=-21
# Episode 223: steps=26,reward=-26
# Episode 224: steps=27,reward=-27
# Episode 225: steps=27,reward=-27
# Episode 226: steps=19,reward=-19
# Episode 227: steps=15,reward=-15
# Episode 228: steps=40,reward=-139
# Episode 229: steps=19,reward=-19
# Episode 230: steps=26,reward=-26
# Episode 231: steps=24,reward=-24
# Episode 232: steps=37,reward=-37
# Episode 233: steps=22,reward=-22
# Episode 234: steps=20,reward=-20
# Episode 235: steps=21,reward=-21
# Episode 236: steps=25,reward=-25
# Episode 237: steps=24,reward=-24
# Episode 238: steps=21,reward=-21
# Episode 239: steps=28,reward=-28
# Episode 240: steps=40,reward=-238
# Episode 241: steps=20,reward=-20
# Episode 242: steps=15,reward=-15
# Episode 243: steps=21,reward=-21
# Episode 244: steps=22,reward=-22
# Episode 245: steps=15,reward=-15
# Episode 246: steps=17,reward=-17
# Episode 247: steps=31,reward=-31
# Episode 248: steps=21,reward=-21
# Episode 249: steps=23,reward=-23
# Episode 250: steps=21,reward=-21
# Episode 251: steps=22,reward=-22
# Episode 252: steps=19,reward=-19
# Episode 253: steps=23,reward=-23
# Episode 254: steps=20,reward=-20
# Episode 255: steps=29,reward=-128
# Episode 256: steps=27,reward=-27
# Episode 257: steps=17,reward=-17
# Episode 258: steps=21,reward=-21
# Episode 259: steps=21,reward=-21
# Episode 260: steps=19,reward=-19
# Episode 261: steps=23,reward=-23
# Episode 262: steps=27,reward=-27
# Episode 263: steps=17,reward=-17
# Episode 264: steps=25,reward=-25
# Episode 265: steps=25,reward=-25
# Episode 266: steps=19,reward=-19
# Episode 267: steps=23,reward=-23
# Episode 268: steps=21,reward=-21
# Episode 269: steps=25,reward=-25
# Episode 270: steps=17,reward=-17
# Episode 271: steps=22,reward=-22
# Episode 272: steps=26,reward=-26
# Episode 273: steps=28,reward=-28
# Episode 274: steps=19,reward=-19
# Episode 275: steps=17,reward=-17
# Episode 276: steps=29,reward=-29
# Episode 277: steps=19,reward=-19
# Episode 278: steps=24,reward=-24
# Episode 279: steps=22,reward=-22
# Episode 280: steps=15,reward=-15
# Episode 281: steps=21,reward=-21
# Episode 282: steps=19,reward=-19
# Episode 283: steps=26,reward=-26
# Episode 284: steps=23,reward=-122
# Episode 285: steps=24,reward=-24
# Episode 286: steps=26,reward=-26
# Episode 287: steps=24,reward=-24
# Episode 288: steps=17,reward=-17
# Episode 289: steps=22,reward=-22
# Episode 290: steps=23,reward=-23
# Episode 291: steps=27,reward=-27
# Episode 292: steps=19,reward=-19
# Episode 293: steps=21,reward=-21
# Episode 294: steps=21,reward=-21
# Episode 295: steps=32,reward=-32
# Episode 296: steps=17,reward=-17
# Episode 297: steps=17,reward=-17
# Episode 298: steps=26,reward=-26
# Episode 299: steps=24,reward=-24
# Episode 300: steps=19,reward=-19
# Episode 301: steps=25,reward=-25
# Episode 302: steps=20,reward=-20
# Episode 303: steps=21,reward=-21
# Episode 304: steps=23,reward=-23
# Episode 305: steps=19,reward=-19
# Episode 306: steps=22,reward=-22
# Episode 307: steps=21,reward=-21
# Episode 308: steps=25,reward=-25
# Episode 309: steps=26,reward=-125
# Episode 310: steps=17,reward=-17
# Episode 311: steps=21,reward=-21
# Episode 312: steps=22,reward=-22
# Episode 313: steps=24,reward=-24
# Episode 314: steps=18,reward=-18
# Episode 315: steps=24,reward=-24
# Episode 316: steps=26,reward=-26
# Episode 317: steps=23,reward=-23
# Episode 318: steps=19,reward=-19
# Episode 319: steps=19,reward=-19
# Episode 320: steps=19,reward=-19
# Episode 321: steps=18,reward=-18
# Episode 322: steps=23,reward=-23
# Episode 323: steps=27,reward=-27
# Episode 324: steps=23,reward=-23
# Episode 325: steps=29,reward=-29
# Episode 326: steps=22,reward=-22
# Episode 327: steps=20,reward=-20
# Episode 328: steps=19,reward=-19
# Episode 329: steps=17,reward=-17
# Episode 330: steps=17,reward=-17
# Episode 331: steps=21,reward=-21
# Episode 332: steps=17,reward=-17
# Episode 333: steps=23,reward=-23
# Episode 334: steps=18,reward=-18
# Episode 335: steps=19,reward=-19
# Episode 336: steps=15,reward=-15
# Episode 337: steps=26,reward=-26
# Episode 338: steps=24,reward=-24
# Episode 339: steps=29,reward=-29
# Episode 340: steps=19,reward=-19
# Episode 341: steps=19,reward=-19
# Episode 342: steps=21,reward=-21
# Episode 343: steps=24,reward=-123
# Episode 344: steps=22,reward=-22
# Episode 345: steps=20,reward=-20
# Episode 346: steps=19,reward=-19
# Episode 347: steps=17,reward=-17
# Episode 348: steps=17,reward=-17
# Episode 349: steps=22,reward=-22
# Episode 350: steps=17,reward=-17
# Episode 351: steps=21,reward=-120
# Episode 352: steps=17,reward=-17
# Episode 353: steps=17,reward=-17
# Episode 354: steps=23,reward=-23
# Episode 355: steps=19,reward=-19
# Episode 356: steps=20,reward=-20
# Episode 357: steps=24,reward=-24
# Episode 358: steps=23,reward=-23
# Episode 359: steps=19,reward=-19
# Episode 360: steps=17,reward=-17
# Episode 361: steps=19,reward=-19
# Episode 362: steps=20,reward=-119
# Episode 363: steps=19,reward=-19
# Episode 364: steps=22,reward=-22
# Episode 365: steps=19,reward=-19
# Episode 366: steps=17,reward=-17
# Episode 367: steps=15,reward=-15
# Episode 368: steps=21,reward=-21
# Episode 369: steps=29,reward=-29
# Episode 370: steps=17,reward=-17
# Episode 371: steps=18,reward=-18
# Episode 372: steps=16,reward=-16
# Episode 373: steps=18,reward=-18
# Episode 374: steps=17,reward=-17
# Episode 375: steps=19,reward=-19
# Episode 376: steps=17,reward=-17
# Episode 377: steps=19,reward=-19
# Episode 378: steps=17,reward=-17
# Episode 379: steps=15,reward=-15
# Episode 380: steps=17,reward=-17
# Episode 381: steps=21,reward=-21
# Episode 382: steps=17,reward=-17
# Episode 383: steps=17,reward=-17
# Episode 384: steps=19,reward=-19
# Episode 385: steps=16,reward=-16
# Episode 386: steps=17,reward=-17
# Episode 387: steps=15,reward=-15
# Episode 388: steps=17,reward=-17
# Episode 389: steps=19,reward=-19
# Episode 390: steps=17,reward=-17
# Episode 391: steps=19,reward=-19
# Episode 392: steps=25,reward=-25
# Episode 393: steps=15,reward=-15
# Episode 394: steps=20,reward=-20
# Episode 395: steps=23,reward=-23
# Episode 396: steps=15,reward=-15
# Episode 397: steps=15,reward=-15
# Episode 398: steps=19,reward=-19
# Episode 399: steps=17,reward=-17
# Episode 400: steps=16,reward=-16
# Episode 401: steps=25,reward=-25
# Episode 402: steps=21,reward=-21
# Episode 403: steps=15,reward=-15
# Episode 404: steps=27,reward=-27
# Episode 405: steps=21,reward=-21
# Episode 406: steps=21,reward=-21
# Episode 407: steps=15,reward=-15
# Episode 408: steps=19,reward=-19
# Episode 409: steps=17,reward=-17
# Episode 410: steps=20,reward=-20
# Episode 411: steps=18,reward=-18
# Episode 412: steps=33,reward=-132
# Episode 413: steps=17,reward=-17
# Episode 414: steps=15,reward=-15
# Episode 415: steps=16,reward=-16
# Episode 416: steps=15,reward=-15
# Episode 417: steps=27,reward=-126
# Episode 418: steps=17,reward=-17
# Episode 419: steps=15,reward=-15
# Episode 420: steps=15,reward=-15
# Episode 421: steps=17,reward=-17
# Episode 422: steps=17,reward=-17
# Episode 423: steps=17,reward=-17
# Episode 424: steps=17,reward=-17
# Episode 425: steps=15,reward=-15
# Episode 426: steps=19,reward=-19
# Episode 427: steps=15,reward=-15
# Episode 428: steps=16,reward=-16
# Episode 429: steps=19,reward=-19
# Episode 430: steps=25,reward=-25
# Episode 431: steps=15,reward=-15
# Episode 432: steps=15,reward=-15
# Episode 433: steps=17,reward=-17
# Episode 434: steps=21,reward=-21
# Episode 435: steps=15,reward=-15
# Episode 436: steps=18,reward=-117
# Episode 437: steps=15,reward=-15
# Episode 438: steps=15,reward=-15
# Episode 439: steps=17,reward=-17
# Episode 440: steps=15,reward=-15
# Episode 441: steps=19,reward=-19
# Episode 442: steps=18,reward=-18
# Episode 443: steps=18,reward=-18
# Episode 444: steps=17,reward=-17
# Episode 445: steps=17,reward=-17
# Episode 446: steps=17,reward=-17
# Episode 447: steps=17,reward=-17
# Episode 448: steps=22,reward=-22
# Episode 449: steps=21,reward=-21
# Episode 450: steps=21,reward=-21
# Episode 451: steps=19,reward=-19
# Episode 452: steps=17,reward=-17
# Episode 453: steps=18,reward=-18
# Episode 454: steps=17,reward=-17
# Episode 455: steps=23,reward=-23
# Episode 456: steps=16,reward=-16
# Episode 457: steps=21,reward=-21
# Episode 458: steps=27,reward=-27
# Episode 459: steps=17,reward=-17
# Episode 460: steps=33,reward=-132
# Episode 461: steps=19,reward=-19
# Episode 462: steps=21,reward=-21
# Episode 463: steps=17,reward=-17
# Episode 464: steps=17,reward=-17
# Episode 465: steps=17,reward=-17
# Episode 466: steps=19,reward=-19
# Episode 467: steps=17,reward=-17
# Episode 468: steps=17,reward=-17
# Episode 469: steps=18,reward=-18
# Episode 470: steps=20,reward=-20
# Episode 471: steps=25,reward=-25
# Episode 472: steps=18,reward=-18
# Episode 473: steps=19,reward=-19
# Episode 474: steps=26,reward=-26
# Episode 475: steps=20,reward=-119
# Episode 476: steps=19,reward=-19
# Episode 477: steps=19,reward=-19
# Episode 478: steps=25,reward=-25
# Episode 479: steps=20,reward=-20
# Episode 480: steps=17,reward=-17
# Episode 481: steps=26,reward=-26
# Episode 482: steps=20,reward=-20
# Episode 483: steps=19,reward=-19
# Episode 484: steps=19,reward=-19
# Episode 485: steps=17,reward=-17
# Episode 486: steps=19,reward=-19
# Episode 487: steps=17,reward=-17
# Episode 488: steps=18,reward=-18
# Episode 489: steps=17,reward=-17
# Episode 490: steps=21,reward=-21
# Episode 491: steps=17,reward=-17
# Episode 492: steps=18,reward=-18
# Episode 493: steps=27,reward=-27
# Episode 494: steps=19,reward=-19
# Episode 495: steps=22,reward=-22
# Episode 496: steps=22,reward=-22
# Episode 497: steps=19,reward=-19
# Episode 498: steps=21,reward=-21
# Episode 499: steps=20,reward=-20
# Episode 500: steps=17,reward=-17
# Episode 501: steps=20,reward=-20
# Episode 502: steps=19,reward=-19
# Episode 503: steps=19,reward=-19
# Episode 504: steps=17,reward=-17
# Episode 505: steps=19,reward=-19
# Episode 506: steps=23,reward=-23
# Episode 507: steps=17,reward=-17
# Episode 508: steps=19,reward=-19
# Episode 509: steps=17,reward=-17
# Episode 510: steps=23,reward=-221
# Episode 511: steps=17,reward=-17
# Episode 512: steps=19,reward=-19
# Episode 513: steps=21,reward=-21
# Episode 514: steps=17,reward=-17
# Episode 515: steps=17,reward=-17
# Episode 516: steps=25,reward=-25
# Episode 517: steps=18,reward=-18
# Episode 518: steps=18,reward=-18
# Episode 519: steps=17,reward=-17
# Episode 520: steps=17,reward=-17
# Episode 521: steps=19,reward=-19
# Episode 522: steps=17,reward=-17
# Episode 523: steps=21,reward=-21
# Episode 524: steps=17,reward=-17
# Episode 525: steps=19,reward=-19
# Episode 526: steps=22,reward=-22
# Episode 527: steps=19,reward=-19
# Episode 528: steps=17,reward=-17
# Episode 529: steps=21,reward=-21
# Episode 530: steps=18,reward=-18
# Episode 531: steps=20,reward=-20
# Episode 532: steps=17,reward=-17
# Episode 533: steps=17,reward=-17
# Episode 534: steps=18,reward=-18
# Episode 535: steps=31,reward=-130
# Episode 536: steps=21,reward=-21
# Episode 537: steps=44,reward=-143
# Episode 538: steps=17,reward=-17
# Episode 539: steps=22,reward=-22
# Episode 540: steps=19,reward=-19
# Episode 541: steps=19,reward=-19
# Episode 542: steps=18,reward=-18
# Episode 543: steps=19,reward=-19
# Episode 544: steps=17,reward=-17
# Episode 545: steps=19,reward=-19
# Episode 546: steps=19,reward=-19
# Episode 547: steps=17,reward=-17
# Episode 548: steps=17,reward=-17
# Episode 549: steps=21,reward=-21
# Episode 550: steps=17,reward=-17
# Episode 551: steps=17,reward=-17
# Episode 552: steps=18,reward=-18
# Episode 553: steps=17,reward=-17
# Episode 554: steps=17,reward=-17
# Episode 555: steps=17,reward=-17
# Episode 556: steps=20,reward=-20
# Episode 557: steps=17,reward=-17
# Episode 558: steps=19,reward=-19
# Episode 559: steps=17,reward=-17
# Episode 560: steps=18,reward=-18
# Episode 561: steps=20,reward=-20
# Episode 562: steps=17,reward=-17
# Episode 563: steps=17,reward=-17
# Episode 564: steps=19,reward=-19
# Episode 565: steps=23,reward=-23
# Episode 566: steps=19,reward=-19
# Episode 567: steps=19,reward=-19
# Episode 568: steps=20,reward=-20
# Episode 569: steps=22,reward=-22
# Episode 570: steps=18,reward=-18
# Episode 571: steps=18,reward=-18
# Episode 572: steps=20,reward=-20
# Episode 573: steps=17,reward=-17
# Episode 574: steps=21,reward=-21
# Episode 575: steps=18,reward=-18
# Episode 576: steps=19,reward=-19
# Episode 577: steps=17,reward=-17
# Episode 578: steps=21,reward=-21
# Episode 579: steps=18,reward=-18
# Episode 580: steps=17,reward=-17
# Episode 581: steps=20,reward=-20
# Episode 582: steps=18,reward=-18
# Episode 583: steps=20,reward=-20
# Episode 584: steps=19,reward=-19
# Episode 585: steps=18,reward=-18
# Episode 586: steps=18,reward=-18
# Episode 587: steps=18,reward=-18
# Episode 588: steps=20,reward=-20
# Episode 589: steps=17,reward=-17
# Episode 590: steps=17,reward=-17
# Episode 591: steps=17,reward=-17
# Episode 592: steps=19,reward=-19
# Episode 593: steps=18,reward=-117
# Episode 594: steps=17,reward=-17
# Episode 595: steps=19,reward=-19
# Episode 596: steps=19,reward=-19
# Episode 597: steps=19,reward=-19
# Episode 598: steps=18,reward=-18
# Episode 599: steps=17,reward=-17
# Episode 600: steps=23,reward=-23
# Episode 601: steps=17,reward=-17
# Episode 602: steps=19,reward=-19
# Episode 603: steps=19,reward=-19
# Episode 604: steps=19,reward=-19
# Episode 605: steps=19,reward=-19
# Episode 606: steps=18,reward=-18
# Episode 607: steps=19,reward=-19
# Episode 608: steps=20,reward=-20
# Episode 609: steps=20,reward=-119
# Episode 610: steps=20,reward=-20
# Episode 611: steps=17,reward=-17
# Episode 612: steps=19,reward=-19
# Episode 613: steps=18,reward=-18
# Episode 614: steps=20,reward=-20
# Episode 615: steps=17,reward=-17
# Episode 616: steps=17,reward=-17
# Episode 617: steps=19,reward=-19
# Episode 618: steps=18,reward=-18
# Episode 619: steps=20,reward=-20
# Episode 620: steps=20,reward=-20
# Episode 621: steps=21,reward=-21
# Episode 622: steps=18,reward=-18
# Episode 623: steps=19,reward=-19
# Episode 624: steps=20,reward=-20
# Episode 625: steps=17,reward=-17
# Episode 626: steps=18,reward=-18
# Episode 627: steps=19,reward=-19
# Episode 628: steps=17,reward=-17
# Episode 629: steps=17,reward=-17
# Episode 630: steps=19,reward=-19
# Episode 631: steps=21,reward=-21
# Episode 632: steps=19,reward=-19
# Episode 633: steps=17,reward=-17
# Episode 634: steps=18,reward=-18
# Episode 635: steps=22,reward=-22
# Episode 636: steps=17,reward=-17
# Episode 637: steps=27,reward=-27
# Episode 638: steps=19,reward=-19
# Episode 639: steps=17,reward=-17
# Episode 640: steps=22,reward=-121
# Episode 641: steps=19,reward=-19
# Episode 642: steps=17,reward=-17
# Episode 643: steps=19,reward=-19
# Episode 644: steps=19,reward=-19
# Episode 645: steps=17,reward=-17
# Episode 646: steps=21,reward=-21
# Episode 647: steps=19,reward=-19
# Episode 648: steps=24,reward=-24
# Episode 649: steps=21,reward=-21
# Episode 650: steps=17,reward=-17
# Episode 651: steps=17,reward=-17
# Episode 652: steps=19,reward=-19
# Episode 653: steps=19,reward=-19
# Episode 654: steps=17,reward=-17
# Episode 655: steps=19,reward=-19
# Episode 656: steps=17,reward=-17
# Episode 657: steps=17,reward=-17
# Episode 658: steps=17,reward=-17
# Episode 659: steps=18,reward=-18
# Episode 660: steps=17,reward=-17
# Episode 661: steps=17,reward=-17
# Episode 662: steps=17,reward=-17
# Episode 663: steps=17,reward=-17
# Episode 664: steps=19,reward=-19
# Episode 665: steps=20,reward=-20
# Episode 666: steps=21,reward=-21
# Episode 667: steps=17,reward=-17
# Episode 668: steps=19,reward=-19
# Episode 669: steps=19,reward=-19
# Episode 670: steps=17,reward=-17
# Episode 671: steps=17,reward=-17
# Episode 672: steps=18,reward=-18
# Episode 673: steps=19,reward=-19
# Episode 674: steps=17,reward=-17
# Episode 675: steps=20,reward=-20
# Episode 676: steps=21,reward=-21
# Episode 677: steps=19,reward=-19
# Episode 678: steps=18,reward=-117
# Episode 679: steps=18,reward=-18
# Episode 680: steps=26,reward=-125
# Episode 681: steps=18,reward=-18
# Episode 682: steps=20,reward=-20
# Episode 683: steps=25,reward=-124
# Episode 684: steps=19,reward=-19
# Episode 685: steps=17,reward=-17
# Episode 686: steps=21,reward=-21
# Episode 687: steps=28,reward=-28
# Episode 688: steps=20,reward=-20
# Episode 689: steps=17,reward=-17
# Episode 690: steps=18,reward=-18
# Episode 691: steps=41,reward=-140
# Episode 692: steps=19,reward=-19
# Episode 693: steps=22,reward=-22
# Episode 694: steps=19,reward=-19
# Episode 695: steps=20,reward=-20
# Episode 696: steps=19,reward=-19
# Episode 697: steps=17,reward=-17
# Episode 698: steps=17,reward=-17
# Episode 699: steps=17,reward=-17
# Episode 700: steps=17,reward=-17
# Episode 701: steps=18,reward=-18
# Episode 702: steps=22,reward=-22
# Episode 703: steps=17,reward=-17
# Episode 704: steps=17,reward=-17
# Episode 705: steps=17,reward=-17
# Episode 706: steps=17,reward=-17
# Episode 707: steps=19,reward=-19
# Episode 708: steps=19,reward=-19
# Episode 709: steps=21,reward=-21
# Episode 710: steps=18,reward=-18
# Episode 711: steps=17,reward=-17
# Episode 712: steps=19,reward=-19
# Episode 713: steps=17,reward=-17
# Episode 714: steps=20,reward=-20
# Episode 715: steps=19,reward=-19
# Episode 716: steps=18,reward=-18
# Episode 717: steps=22,reward=-22
# Episode 718: steps=19,reward=-19
# Episode 719: steps=17,reward=-17
# Episode 720: steps=20,reward=-119
# Episode 721: steps=17,reward=-17
# Episode 722: steps=19,reward=-19
# Episode 723: steps=19,reward=-19
# Episode 724: steps=17,reward=-17
# Episode 725: steps=19,reward=-19
# Episode 726: steps=17,reward=-17
# Episode 727: steps=17,reward=-17
# Episode 728: steps=18,reward=-18
# Episode 729: steps=21,reward=-21
# Episode 730: steps=18,reward=-18
# Episode 731: steps=20,reward=-20
# Episode 732: steps=17,reward=-17
# Episode 733: steps=17,reward=-17
# Episode 734: steps=19,reward=-19
# Episode 735: steps=21,reward=-21
# Episode 736: steps=17,reward=-17
# Episode 737: steps=21,reward=-21
# Episode 738: steps=18,reward=-18
# Episode 739: steps=23,reward=-23
# Episode 740: steps=19,reward=-19
# Episode 741: steps=20,reward=-20
# Episode 742: steps=17,reward=-17
# Episode 743: steps=19,reward=-19
# Episode 744: steps=17,reward=-17
# Episode 745: steps=17,reward=-17
# Episode 746: steps=24,reward=-123
# Episode 747: steps=17,reward=-17
# Episode 748: steps=18,reward=-18
# Episode 749: steps=19,reward=-19
# Episode 750: steps=19,reward=-19
# Episode 751: steps=19,reward=-19
# Episode 752: steps=17,reward=-17
# Episode 753: steps=17,reward=-17
# Episode 754: steps=20,reward=-20
# Episode 755: steps=17,reward=-17
# Episode 756: steps=17,reward=-17
# Episode 757: steps=17,reward=-17
# Episode 758: steps=20,reward=-20
# Episode 759: steps=17,reward=-17
# Episode 760: steps=17,reward=-17
# Episode 761: steps=18,reward=-18
# Episode 762: steps=18,reward=-18
# Episode 763: steps=18,reward=-18
# Episode 764: steps=17,reward=-17
# Episode 765: steps=18,reward=-18
# Episode 766: steps=17,reward=-17
# Episode 767: steps=17,reward=-17
# Episode 768: steps=17,reward=-17
# Episode 769: steps=26,reward=-26
# Episode 770: steps=17,reward=-17
# Episode 771: steps=19,reward=-19
# Episode 772: steps=20,reward=-20
# Episode 773: steps=18,reward=-18
# Episode 774: steps=17,reward=-17
# Episode 775: steps=18,reward=-18
# Episode 776: steps=19,reward=-19
# Episode 777: steps=20,reward=-20
# Episode 778: steps=17,reward=-17
# Episode 779: steps=22,reward=-22
# Episode 780: steps=17,reward=-17
# Episode 781: steps=21,reward=-21
# Episode 782: steps=17,reward=-17
# Episode 783: steps=19,reward=-19
# Episode 784: steps=17,reward=-17
# Episode 785: steps=26,reward=-26
# Episode 786: steps=20,reward=-20
# Episode 787: steps=17,reward=-17
# Episode 788: steps=19,reward=-19
# Episode 789: steps=17,reward=-17
# Episode 790: steps=17,reward=-17
# Episode 791: steps=17,reward=-17
# Episode 792: steps=18,reward=-117
# Episode 793: steps=21,reward=-21
# Episode 794: steps=17,reward=-17
# Episode 795: steps=17,reward=-17
# Episode 796: steps=17,reward=-17
# Episode 797: steps=18,reward=-18
# Episode 798: steps=21,reward=-120
# Episode 799: steps=19,reward=-19
# Episode 800: steps=17,reward=-17
# Episode 801: steps=17,reward=-17
# Episode 802: steps=18,reward=-18
# Episode 803: steps=21,reward=-21
# Episode 804: steps=21,reward=-21
# Episode 805: steps=18,reward=-18
# Episode 806: steps=20,reward=-20
# Episode 807: steps=17,reward=-17
# Episode 808: steps=19,reward=-19
# Episode 809: steps=17,reward=-17
# Episode 810: steps=18,reward=-117
# Episode 811: steps=19,reward=-19
# Episode 812: steps=22,reward=-121
# Episode 813: steps=17,reward=-17
# Episode 814: steps=19,reward=-19
# Episode 815: steps=18,reward=-18
# Episode 816: steps=19,reward=-19
# Episode 817: steps=17,reward=-17
# Episode 818: steps=17,reward=-17
# Episode 819: steps=17,reward=-17
# Episode 820: steps=17,reward=-17
# Episode 821: steps=17,reward=-17
# Episode 822: steps=21,reward=-21
# Episode 823: steps=18,reward=-18
# Episode 824: steps=17,reward=-17
# Episode 825: steps=18,reward=-18
# Episode 826: steps=19,reward=-19
# Episode 827: steps=23,reward=-23
# Episode 828: steps=17,reward=-17
# Episode 829: steps=17,reward=-17
# Episode 830: steps=17,reward=-17
# Episode 831: steps=19,reward=-19
# Episode 832: steps=18,reward=-18
# Episode 833: steps=17,reward=-17
# Episode 834: steps=19,reward=-19
# Episode 835: steps=20,reward=-20
# Episode 836: steps=19,reward=-19
# Episode 837: steps=23,reward=-23
# Episode 838: steps=17,reward=-17
# Episode 839: steps=18,reward=-18
# Episode 840: steps=17,reward=-17
# Episode 841: steps=25,reward=-25
# Episode 842: steps=19,reward=-19
# Episode 843: steps=17,reward=-17
# Episode 844: steps=17,reward=-17
# Episode 845: steps=18,reward=-18
# Episode 846: steps=17,reward=-17
# Episode 847: steps=18,reward=-18
# Episode 848: steps=17,reward=-17
# Episode 849: steps=17,reward=-17
# Episode 850: steps=18,reward=-18
# Episode 851: steps=17,reward=-17
# Episode 852: steps=18,reward=-18
# Episode 853: steps=19,reward=-19
# Episode 854: steps=17,reward=-17
# Episode 855: steps=21,reward=-21
# Episode 856: steps=21,reward=-21
# Episode 857: steps=20,reward=-20
# Episode 858: steps=20,reward=-20
# Episode 859: steps=18,reward=-18
# Episode 860: steps=17,reward=-17
# Episode 861: steps=20,reward=-20
# Episode 862: steps=19,reward=-19
# Episode 863: steps=17,reward=-17
# Episode 864: steps=17,reward=-17
# Episode 865: steps=17,reward=-17
# Episode 866: steps=17,reward=-17
# Episode 867: steps=19,reward=-19
# Episode 868: steps=24,reward=-24
# Episode 869: steps=21,reward=-21
# Episode 870: steps=21,reward=-21
# Episode 871: steps=17,reward=-17
# Episode 872: steps=19,reward=-19
# Episode 873: steps=17,reward=-17
# Episode 874: steps=21,reward=-21
# Episode 875: steps=20,reward=-20
# Episode 876: steps=20,reward=-20
# Episode 877: steps=20,reward=-20
# Episode 878: steps=18,reward=-18
# Episode 879: steps=17,reward=-17
# Episode 880: steps=17,reward=-17
# Episode 881: steps=18,reward=-18
# Episode 882: steps=21,reward=-21
# Episode 883: steps=17,reward=-17
# Episode 884: steps=19,reward=-19
# Episode 885: steps=18,reward=-18
# Episode 886: steps=17,reward=-17
# Episode 887: steps=17,reward=-17
# Episode 888: steps=18,reward=-18
# Episode 889: steps=17,reward=-17
# Episode 890: steps=20,reward=-20
# Episode 891: steps=18,reward=-18
# Episode 892: steps=19,reward=-19
# Episode 893: steps=18,reward=-18
# Episode 894: steps=19,reward=-19
# Episode 895: steps=18,reward=-18
# Episode 896: steps=19,reward=-19
# Episode 897: steps=17,reward=-17
# Episode 898: steps=17,reward=-17
# Episode 899: steps=21,reward=-21
# Episode 900: steps=19,reward=-19
# Episode 901: steps=19,reward=-19
# Episode 902: steps=17,reward=-17
# Episode 903: steps=21,reward=-21
# Episode 904: steps=17,reward=-17
# Episode 905: steps=18,reward=-18
# Episode 906: steps=18,reward=-18
# Episode 907: steps=21,reward=-21
# Episode 908: steps=20,reward=-20
# Episode 909: steps=20,reward=-20
# Episode 910: steps=18,reward=-18
# Episode 911: steps=17,reward=-17
# Episode 912: steps=18,reward=-18
# Episode 913: steps=21,reward=-21
# Episode 914: steps=17,reward=-17
# Episode 915: steps=19,reward=-19
# Episode 916: steps=17,reward=-17
# Episode 917: steps=21,reward=-21
# Episode 918: steps=19,reward=-19
# Episode 919: steps=19,reward=-19
# Episode 920: steps=21,reward=-21
# Episode 921: steps=17,reward=-17
# Episode 922: steps=17,reward=-17
# Episode 923: steps=18,reward=-18
# Episode 924: steps=24,reward=-24
# Episode 925: steps=18,reward=-18
# Episode 926: steps=20,reward=-20
# Episode 927: steps=22,reward=-22
# Episode 928: steps=18,reward=-18
# Episode 929: steps=17,reward=-17
# Episode 930: steps=20,reward=-119
# Episode 931: steps=17,reward=-17
# Episode 932: steps=17,reward=-17
# Episode 933: steps=19,reward=-19
# Episode 934: steps=17,reward=-17
# Episode 935: steps=22,reward=-22
# Episode 936: steps=19,reward=-19
# Episode 937: steps=19,reward=-19
# Episode 938: steps=17,reward=-17
# Episode 939: steps=17,reward=-17
# Episode 940: steps=18,reward=-18
# Episode 941: steps=17,reward=-17
# Episode 942: steps=17,reward=-17
# Episode 943: steps=22,reward=-22
# Episode 944: steps=17,reward=-17
# Episode 945: steps=20,reward=-20
# Episode 946: steps=17,reward=-17
# Episode 947: steps=22,reward=-22
# Episode 948: steps=19,reward=-19
# Episode 949: steps=18,reward=-18
# Episode 950: steps=19,reward=-19
# Episode 951: steps=19,reward=-19
# Episode 952: steps=19,reward=-19
# Episode 953: steps=17,reward=-17
# Episode 954: steps=19,reward=-19
# Episode 955: steps=21,reward=-21
# Episode 956: steps=20,reward=-119
# Episode 957: steps=27,reward=-27
# Episode 958: steps=17,reward=-17
# Episode 959: steps=19,reward=-19
# Episode 960: steps=19,reward=-19
# Episode 961: steps=18,reward=-18
# Episode 962: steps=19,reward=-19
# Episode 963: steps=19,reward=-19
# Episode 964: steps=35,reward=-134
# Episode 965: steps=22,reward=-22
# Episode 966: steps=23,reward=-23
# Episode 967: steps=19,reward=-19
# Episode 968: steps=19,reward=-19
# Episode 969: steps=18,reward=-18
# Episode 970: steps=22,reward=-22
# Episode 971: steps=19,reward=-19
# Episode 972: steps=22,reward=-22
# Episode 973: steps=27,reward=-27
# Episode 974: steps=19,reward=-19
# Episode 975: steps=18,reward=-18
# Episode 976: steps=17,reward=-17
# Episode 977: steps=21,reward=-21
# Episode 978: steps=17,reward=-17
# Episode 979: steps=18,reward=-18
# Episode 980: steps=17,reward=-17
# Episode 981: steps=17,reward=-17
# Episode 982: steps=19,reward=-118
# Episode 983: steps=16,reward=-16
# Episode 984: steps=19,reward=-19
# Episode 985: steps=27,reward=-27
# Episode 986: steps=28,reward=-28
# Episode 987: steps=19,reward=-19
# Episode 988: steps=17,reward=-17
# Episode 989: steps=25,reward=-25
# Episode 990: steps=21,reward=-21
# Episode 991: steps=32,reward=-32
# Episode 992: steps=19,reward=-19
# Episode 993: steps=19,reward=-19
# Episode 994: steps=19,reward=-19
# Episode 995: steps=17,reward=-17
# Episode 996: steps=21,reward=-21
# Episode 997: steps=17,reward=-17
# Episode 998: steps=21,reward=-21
# Episode 999: steps=26,reward=-26
# Episode 1000: steps=23,reward=-23
# Episode 1001: steps=18,reward=-18
# Episode 1002: steps=17,reward=-17
# Episode 1003: steps=17,reward=-17
# Episode 1004: steps=36,reward=-135
# Episode 1005: steps=17,reward=-17
# Episode 1006: steps=17,reward=-17
# Episode 1007: steps=17,reward=-17
# Episode 1008: steps=16,reward=-16
# Episode 1009: steps=19,reward=-19
# Episode 1010: steps=17,reward=-17
# Episode 1011: steps=17,reward=-17
# Episode 1012: steps=19,reward=-19
# Episode 1013: steps=21,reward=-21
# Episode 1014: steps=23,reward=-23
# Episode 1015: steps=22,reward=-22
# Episode 1016: steps=21,reward=-21
# Episode 1017: steps=21,reward=-21
# Episode 1018: steps=20,reward=-20
# Episode 1019: steps=17,reward=-17
# Episode 1020: steps=17,reward=-17
# Episode 1021: steps=18,reward=-18
# Episode 1022: steps=20,reward=-20
# Episode 1023: steps=19,reward=-19
# Episode 1024: steps=18,reward=-18
# Episode 1025: steps=19,reward=-19
# Episode 1026: steps=23,reward=-23
# Episode 1027: steps=17,reward=-17
# Episode 1028: steps=17,reward=-17
# Episode 1029: steps=22,reward=-22
# Episode 1030: steps=23,reward=-23
# Episode 1031: steps=19,reward=-19
# Episode 1032: steps=15,reward=-15
# Episode 1033: steps=19,reward=-19
# Episode 1034: steps=20,reward=-20
# Episode 1035: steps=17,reward=-17
# Episode 1036: steps=31,reward=-31
# Episode 1037: steps=22,reward=-22
# Episode 1038: steps=18,reward=-18
# Episode 1039: steps=18,reward=-18
# Episode 1040: steps=23,reward=-23
# Episode 1041: steps=17,reward=-17
# Episode 1042: steps=17,reward=-17
# Episode 1043: steps=20,reward=-20
# Episode 1044: steps=18,reward=-18
# Episode 1045: steps=19,reward=-19
# Episode 1046: steps=22,reward=-22
# Episode 1047: steps=19,reward=-19
# Episode 1048: steps=17,reward=-17
# Episode 1049: steps=19,reward=-19
# Episode 1050: steps=17,reward=-17
# Episode 1051: steps=26,reward=-26
# Episode 1052: steps=19,reward=-19
# Episode 1053: steps=17,reward=-17
# Episode 1054: steps=19,reward=-19
# Episode 1055: steps=20,reward=-20
# Episode 1056: steps=19,reward=-19
# Episode 1057: steps=19,reward=-19
# Episode 1058: steps=17,reward=-17
# Episode 1059: steps=19,reward=-19
# Episode 1060: steps=17,reward=-17
# Episode 1061: steps=17,reward=-17
# Episode 1062: steps=18,reward=-18
# Episode 1063: steps=17,reward=-17
# Episode 1064: steps=19,reward=-19
# Episode 1065: steps=23,reward=-23
# Episode 1066: steps=17,reward=-17
# Episode 1067: steps=19,reward=-19
# Episode 1068: steps=18,reward=-18
# Episode 1069: steps=17,reward=-17
# Episode 1070: steps=17,reward=-17
# Episode 1071: steps=17,reward=-17
# Episode 1072: steps=18,reward=-18
# Episode 1073: steps=19,reward=-19
# Episode 1074: steps=19,reward=-19
# Episode 1075: steps=20,reward=-20
# Episode 1076: steps=17,reward=-17
# Episode 1077: steps=18,reward=-18
# Episode 1078: steps=19,reward=-19
# Episode 1079: steps=17,reward=-17
# Episode 1080: steps=18,reward=-18
# Episode 1081: steps=20,reward=-20
# Episode 1082: steps=17,reward=-17
# Episode 1083: steps=21,reward=-21
# Episode 1084: steps=21,reward=-21
# Episode 1085: steps=17,reward=-17
# Episode 1086: steps=17,reward=-17
# Episode 1087: steps=17,reward=-17
# Episode 1088: steps=18,reward=-18
# Episode 1089: steps=19,reward=-19
# Episode 1090: steps=17,reward=-17
# Episode 1091: steps=18,reward=-18
# Episode 1092: steps=19,reward=-19
# Episode 1093: steps=17,reward=-17
# Episode 1094: steps=17,reward=-17
# Episode 1095: steps=19,reward=-19
# Episode 1096: steps=17,reward=-17
# Episode 1097: steps=18,reward=-18
# Episode 1098: steps=17,reward=-17
# Episode 1099: steps=18,reward=-18
# Episode 1100: steps=18,reward=-18
# Episode 1101: steps=18,reward=-18
# Episode 1102: steps=21,reward=-21
# Episode 1103: steps=19,reward=-19
# Episode 1104: steps=17,reward=-17
# Episode 1105: steps=18,reward=-18
# Episode 1106: steps=17,reward=-17
# Episode 1107: steps=21,reward=-21
# Episode 1108: steps=20,reward=-20
# Episode 1109: steps=17,reward=-17
# Episode 1110: steps=17,reward=-17
# Episode 1111: steps=18,reward=-18
# Episode 1112: steps=18,reward=-18
# Episode 1113: steps=17,reward=-17
# Episode 1114: steps=17,reward=-17
# Episode 1115: steps=18,reward=-18
# Episode 1116: steps=21,reward=-21
# Episode 1117: steps=15,reward=-15
# Episode 1118: steps=17,reward=-17
# Episode 1119: steps=17,reward=-17
# Episode 1120: steps=17,reward=-17
# Episode 1121: steps=19,reward=-19
# Episode 1122: steps=19,reward=-118
# Episode 1123: steps=19,reward=-19
# Episode 1124: steps=21,reward=-21
# Episode 1125: steps=17,reward=-17
# Episode 1126: steps=19,reward=-19
# Episode 1127: steps=15,reward=-15
# Episode 1128: steps=18,reward=-18
# Episode 1129: steps=21,reward=-21
# Episode 1130: steps=17,reward=-17
# Episode 1131: steps=20,reward=-20
# Episode 1132: steps=17,reward=-17
# Episode 1133: steps=18,reward=-18
# Episode 1134: steps=17,reward=-17
# Episode 1135: steps=19,reward=-19
# Episode 1136: steps=19,reward=-19
# Episode 1137: steps=17,reward=-17
# Episode 1138: steps=17,reward=-17
# Episode 1139: steps=17,reward=-17
# Episode 1140: steps=18,reward=-18
# Episode 1141: steps=23,reward=-122
# Episode 1142: steps=19,reward=-19
# Episode 1143: steps=18,reward=-18
# Episode 1144: steps=18,reward=-18
# Episode 1145: steps=20,reward=-20
# Episode 1146: steps=17,reward=-17
# Episode 1147: steps=17,reward=-17
# Episode 1148: steps=19,reward=-19
# Episode 1149: steps=23,reward=-23
# Episode 1150: steps=20,reward=-20
# Episode 1151: steps=17,reward=-17
# Episode 1152: steps=17,reward=-17
# Episode 1153: steps=20,reward=-20
# Episode 1154: steps=17,reward=-17
# Episode 1155: steps=19,reward=-19
# Episode 1156: steps=21,reward=-21
# Episode 1157: steps=21,reward=-21
# Episode 1158: steps=18,reward=-18
# Episode 1159: steps=17,reward=-17
# Episode 1160: steps=20,reward=-20
# Episode 1161: steps=15,reward=-15
# Episode 1162: steps=19,reward=-19
# Episode 1163: steps=18,reward=-18
# Episode 1164: steps=22,reward=-22
# Episode 1165: steps=15,reward=-15
# Episode 1166: steps=17,reward=-17
# Episode 1167: steps=20,reward=-119
# Episode 1168: steps=23,reward=-23
# Episode 1169: steps=19,reward=-19
# Episode 1170: steps=20,reward=-20
# Episode 1171: steps=17,reward=-17
# Episode 1172: steps=17,reward=-17
# Episode 1173: steps=17,reward=-17
# Episode 1174: steps=19,reward=-19
# Episode 1175: steps=19,reward=-19
# Episode 1176: steps=20,reward=-20
# Episode 1177: steps=17,reward=-17
# Episode 1178: steps=17,reward=-17
# Episode 1179: steps=15,reward=-15
# Episode 1180: steps=32,reward=-32
# Episode 1181: steps=17,reward=-17
# Episode 1182: steps=20,reward=-20
# Episode 1183: steps=20,reward=-20
# Episode 1184: steps=17,reward=-17
# Episode 1185: steps=17,reward=-17
# Episode 1186: steps=17,reward=-17
# Episode 1187: steps=17,reward=-17
# Episode 1188: steps=17,reward=-17
# Episode 1189: steps=19,reward=-19
# Episode 1190: steps=17,reward=-17
# Episode 1191: steps=18,reward=-18
# Episode 1192: steps=19,reward=-19
# Episode 1193: steps=18,reward=-18
# Episode 1194: steps=20,reward=-20
# Episode 1195: steps=19,reward=-19
# Episode 1196: steps=17,reward=-17
# Episode 1197: steps=19,reward=-19
# Episode 1198: steps=18,reward=-117
# Episode 1199: steps=18,reward=-117
# Episode 1200: steps=19,reward=-19
# Episode 1201: steps=17,reward=-17
# Episode 1202: steps=20,reward=-20
# Episode 1203: steps=22,reward=-22
# Episode 1204: steps=17,reward=-17
# Episode 1205: steps=17,reward=-17
# Episode 1206: steps=17,reward=-17
# Episode 1207: steps=19,reward=-19
# Episode 1208: steps=18,reward=-18
# Episode 1209: steps=20,reward=-20
# Episode 1210: steps=20,reward=-20
# Episode 1211: steps=19,reward=-19
# Episode 1212: steps=17,reward=-17
# Episode 1213: steps=17,reward=-17
# Episode 1214: steps=18,reward=-18
# Episode 1215: steps=17,reward=-17
# Episode 1216: steps=20,reward=-20
# Episode 1217: steps=21,reward=-21
# Episode 1218: steps=17,reward=-17
# Episode 1219: steps=19,reward=-19
# Episode 1220: steps=19,reward=-19
# Episode 1221: steps=21,reward=-21
# Episode 1222: steps=19,reward=-19
# Episode 1223: steps=17,reward=-17
# Episode 1224: steps=18,reward=-18
# Episode 1225: steps=19,reward=-19
# Episode 1226: steps=19,reward=-19
# Episode 1227: steps=17,reward=-17
# Episode 1228: steps=18,reward=-18
# Episode 1229: steps=17,reward=-17
# Episode 1230: steps=18,reward=-18
# Episode 1231: steps=17,reward=-17
# Episode 1232: steps=19,reward=-19
# Episode 1233: steps=19,reward=-19
# Episode 1234: steps=21,reward=-21
# Episode 1235: steps=19,reward=-19
# Episode 1236: steps=19,reward=-19
# Episode 1237: steps=21,reward=-120
# Episode 1238: steps=19,reward=-19
# Episode 1239: steps=19,reward=-19
# Episode 1240: steps=21,reward=-21
# Episode 1241: steps=17,reward=-17
# Episode 1242: steps=18,reward=-18
# Episode 1243: steps=18,reward=-18
# Episode 1244: steps=18,reward=-18
# Episode 1245: steps=17,reward=-17
# Episode 1246: steps=21,reward=-21
# Episode 1247: steps=17,reward=-17
# Episode 1248: steps=17,reward=-17
# Episode 1249: steps=20,reward=-20
# Episode 1250: steps=18,reward=-18
# Episode 1251: steps=20,reward=-20
# Episode 1252: steps=18,reward=-18
# Episode 1253: steps=18,reward=-18
# Episode 1254: steps=17,reward=-17
# Episode 1255: steps=18,reward=-18
# Episode 1256: steps=17,reward=-17
# Episode 1257: steps=18,reward=-18
# Episode 1258: steps=17,reward=-17
# Episode 1259: steps=17,reward=-17
# Episode 1260: steps=18,reward=-18
# Episode 1261: steps=17,reward=-17
# Episode 1262: steps=22,reward=-22
# Episode 1263: steps=17,reward=-17
# Episode 1264: steps=19,reward=-19
# Episode 1265: steps=17,reward=-17
# Episode 1266: steps=21,reward=-21
# Episode 1267: steps=18,reward=-18
# Episode 1268: steps=17,reward=-17
# Episode 1269: steps=18,reward=-18
# Episode 1270: steps=18,reward=-18
# Episode 1271: steps=19,reward=-19
# Episode 1272: steps=17,reward=-17
# Episode 1273: steps=24,reward=-24
# Episode 1274: steps=19,reward=-19
# Episode 1275: steps=18,reward=-18
# Episode 1276: steps=19,reward=-19
# Episode 1277: steps=17,reward=-17
# Episode 1278: steps=19,reward=-19
# Episode 1279: steps=20,reward=-20
# Episode 1280: steps=17,reward=-17
# Episode 1281: steps=19,reward=-19
# Episode 1282: steps=17,reward=-17
# Episode 1283: steps=19,reward=-118
# Episode 1284: steps=19,reward=-19
# Episode 1285: steps=17,reward=-17
# Episode 1286: steps=18,reward=-18
# Episode 1287: steps=21,reward=-21
# Episode 1288: steps=19,reward=-19
# Episode 1289: steps=19,reward=-19
# Episode 1290: steps=18,reward=-18
# Episode 1291: steps=18,reward=-18
# Episode 1292: steps=19,reward=-19
# Episode 1293: steps=19,reward=-19
# Episode 1294: steps=23,reward=-23
# Episode 1295: steps=25,reward=-25
# Episode 1296: steps=18,reward=-18
# Episode 1297: steps=17,reward=-17
# Episode 1298: steps=17,reward=-17
# Episode 1299: steps=17,reward=-17
# Episode 1300: steps=18,reward=-18
# Episode 1301: steps=18,reward=-18
# Episode 1302: steps=18,reward=-117
# Episode 1303: steps=17,reward=-17
# Episode 1304: steps=17,reward=-17
# Episode 1305: steps=19,reward=-19
# Episode 1306: steps=17,reward=-17
# Episode 1307: steps=19,reward=-19
# Episode 1308: steps=18,reward=-18
# Episode 1309: steps=17,reward=-17
# Episode 1310: steps=18,reward=-18
# Episode 1311: steps=19,reward=-19
# Episode 1312: steps=17,reward=-17
# Episode 1313: steps=19,reward=-118
# Episode 1314: steps=19,reward=-19
# Episode 1315: steps=20,reward=-20
# Episode 1316: steps=20,reward=-20
# Episode 1317: steps=21,reward=-21
# Episode 1318: steps=17,reward=-17
# Episode 1319: steps=19,reward=-19
# Episode 1320: steps=21,reward=-21
# Episode 1321: steps=18,reward=-18
# Episode 1322: steps=17,reward=-17
# Episode 1323: steps=17,reward=-17
# Episode 1324: steps=20,reward=-20
# Episode 1325: steps=19,reward=-19
# Episode 1326: steps=17,reward=-17
# Episode 1327: steps=17,reward=-17
# Episode 1328: steps=21,reward=-21
# Episode 1329: steps=17,reward=-17
# Episode 1330: steps=19,reward=-19
# Episode 1331: steps=22,reward=-22
# Episode 1332: steps=19,reward=-19
# Episode 1333: steps=17,reward=-17
# Episode 1334: steps=19,reward=-19
# Episode 1335: steps=21,reward=-21
# Episode 1336: steps=20,reward=-20
# Episode 1337: steps=17,reward=-17
# Episode 1338: steps=17,reward=-17
# Episode 1339: steps=19,reward=-19
# Episode 1340: steps=17,reward=-17
# Episode 1341: steps=17,reward=-17
# Episode 1342: steps=17,reward=-17
# Episode 1343: steps=17,reward=-17
# Episode 1344: steps=17,reward=-17
# Episode 1345: steps=21,reward=-120
# Episode 1346: steps=19,reward=-19
# Episode 1347: steps=17,reward=-17
# Episode 1348: steps=28,reward=-28
# Episode 1349: steps=17,reward=-17
# Episode 1350: steps=21,reward=-21
# Episode 1351: steps=18,reward=-18
# Episode 1352: steps=17,reward=-17
# Episode 1353: steps=18,reward=-18
# Episode 1354: steps=19,reward=-19
# Episode 1355: steps=18,reward=-18
# Episode 1356: steps=17,reward=-17
# Episode 1357: steps=17,reward=-17
# Episode 1358: steps=19,reward=-19
# Episode 1359: steps=22,reward=-22
# Episode 1360: steps=17,reward=-17
# Episode 1361: steps=21,reward=-21
# Episode 1362: steps=17,reward=-17
# Episode 1363: steps=17,reward=-17
# Episode 1364: steps=17,reward=-17
# Episode 1365: steps=17,reward=-17
# Episode 1366: steps=19,reward=-19
# Episode 1367: steps=20,reward=-20
# Episode 1368: steps=20,reward=-119
# Episode 1369: steps=18,reward=-18
# Episode 1370: steps=17,reward=-17
# Episode 1371: steps=17,reward=-17
# Episode 1372: steps=19,reward=-19
# Episode 1373: steps=22,reward=-22
# Episode 1374: steps=19,reward=-19
# Episode 1375: steps=19,reward=-19
# Episode 1376: steps=18,reward=-18
# Episode 1377: steps=17,reward=-17
# Episode 1378: steps=18,reward=-18
# Episode 1379: steps=17,reward=-17
# Episode 1380: steps=19,reward=-19
# Episode 1381: steps=18,reward=-18
# Episode 1382: steps=18,reward=-18
# Episode 1383: steps=18,reward=-18
# Episode 1384: steps=17,reward=-17
# Episode 1385: steps=19,reward=-19
# Episode 1386: steps=19,reward=-19
# Episode 1387: steps=17,reward=-17
# Episode 1388: steps=21,reward=-21
# Episode 1389: steps=17,reward=-17
# Episode 1390: steps=32,reward=-131
# Episode 1391: steps=18,reward=-18
# Episode 1392: steps=17,reward=-17
# Episode 1393: steps=18,reward=-18
# Episode 1394: steps=17,reward=-17
# Episode 1395: steps=17,reward=-17
# Episode 1396: steps=17,reward=-17
# Episode 1397: steps=24,reward=-24
# Episode 1398: steps=17,reward=-17
# Episode 1399: steps=19,reward=-19
# Episode 1400: steps=17,reward=-17
# Episode 1401: steps=17,reward=-17
# Episode 1402: steps=17,reward=-17
# Episode 1403: steps=25,reward=-25
# Episode 1404: steps=17,reward=-17
# Episode 1405: steps=19,reward=-19
# Episode 1406: steps=19,reward=-19
# Episode 1407: steps=20,reward=-20
# Episode 1408: steps=17,reward=-17
# Episode 1409: steps=17,reward=-17
# Episode 1410: steps=17,reward=-17
# Episode 1411: steps=19,reward=-19
# Episode 1412: steps=17,reward=-17
# Episode 1413: steps=17,reward=-17
# Episode 1414: steps=19,reward=-19
# Episode 1415: steps=19,reward=-19
# Episode 1416: steps=17,reward=-17
# Episode 1417: steps=19,reward=-118
# Episode 1418: steps=21,reward=-21
# Episode 1419: steps=21,reward=-21
# Episode 1420: steps=21,reward=-21
# Episode 1421: steps=17,reward=-17
# Episode 1422: steps=18,reward=-18
# Episode 1423: steps=17,reward=-17
# Episode 1424: steps=17,reward=-17
# Episode 1425: steps=17,reward=-17
# Episode 1426: steps=19,reward=-19
# Episode 1427: steps=18,reward=-117
# Episode 1428: steps=18,reward=-18
# Episode 1429: steps=17,reward=-17
# Episode 1430: steps=17,reward=-17
# Episode 1431: steps=17,reward=-17
# Episode 1432: steps=17,reward=-17
# Episode 1433: steps=18,reward=-18
# Episode 1434: steps=17,reward=-17
# Episode 1435: steps=17,reward=-17
# Episode 1436: steps=18,reward=-18
# Episode 1437: steps=19,reward=-19
# Episode 1438: steps=17,reward=-17
# Episode 1439: steps=17,reward=-17
# Episode 1440: steps=22,reward=-22
# ...
# Episode 9537: steps=17,reward=-17
# Episode 9538: steps=18,reward=-18
# Episode 9539: steps=18,reward=-18
# Episode 9540: steps=21,reward=-21
# Episode 9541: steps=19,reward=-19
# Episode 9542: steps=19,reward=-19
# Episode 9543: steps=17,reward=-17
# Episode 9544: steps=17,reward=-17
# Episode 9545: steps=19,reward=-19
# Episode 9546: steps=17,reward=-17
# Episode 9547: steps=18,reward=-18
# Episode 9548: steps=20,reward=-20
# Episode 9549: steps=17,reward=-17
# Episode 9550: steps=19,reward=-19
# Episode 9551: steps=21,reward=-21
# Episode 9552: steps=17,reward=-17
# Episode 9553: steps=18,reward=-18
# Episode 9554: steps=20,reward=-20
# Episode 9555: steps=20,reward=-20
# Episode 9556: steps=17,reward=-17
# Episode 9557: steps=17,reward=-17
# Episode 9558: steps=18,reward=-18
# Episode 9559: steps=17,reward=-17
# Episode 9560: steps=17,reward=-17
# Episode 9561: steps=21,reward=-21
# Episode 9562: steps=17,reward=-17
# Episode 9563: steps=18,reward=-18
# Episode 9564: steps=17,reward=-17
# Episode 9565: steps=19,reward=-19
# Episode 9566: steps=17,reward=-17
# Episode 9567: steps=19,reward=-19
# Episode 9568: steps=17,reward=-17
# Episode 9569: steps=17,reward=-17
# Episode 9570: steps=17,reward=-17
# Episode 9571: steps=19,reward=-19
# Episode 9572: steps=17,reward=-17
# Episode 9573: steps=15,reward=-15
# Episode 9574: steps=15,reward=-15
# Episode 9575: steps=16,reward=-16
# Episode 9576: steps=17,reward=-17
# Episode 9577: steps=15,reward=-15
# Episode 9578: steps=18,reward=-18
# Episode 9579: steps=15,reward=-15
# Episode 9580: steps=17,reward=-17
# Episode 9581: steps=15,reward=-15
# Episode 9582: steps=15,reward=-15
# Episode 9583: steps=16,reward=-16
# Episode 9584: steps=15,reward=-15
# Episode 9585: steps=15,reward=-15
# Episode 9586: steps=19,reward=-19
# Episode 9587: steps=18,reward=-18
# Episode 9588: steps=19,reward=-19
# Episode 9589: steps=15,reward=-15
# Episode 9590: steps=18,reward=-18
# Episode 9591: steps=17,reward=-17
# Episode 9592: steps=15,reward=-15
# Episode 9593: steps=17,reward=-17
# Episode 9594: steps=17,reward=-17
# Episode 9595: steps=15,reward=-15
# Episode 9596: steps=17,reward=-17
# Episode 9597: steps=21,reward=-21
# Episode 9598: steps=16,reward=-16
# Episode 9599: steps=15,reward=-15
# Episode 9600: steps=17,reward=-17
# Episode 9601: steps=15,reward=-15
# Episode 9602: steps=19,reward=-19
# Episode 9603: steps=17,reward=-17
# Episode 9604: steps=15,reward=-15
# Episode 9605: steps=17,reward=-17
# Episode 9606: steps=15,reward=-15
# Episode 9607: steps=17,reward=-17
# Episode 9608: steps=19,reward=-19
# Episode 9609: steps=17,reward=-17
# Episode 9610: steps=15,reward=-15
# Episode 9611: steps=17,reward=-17
# Episode 9612: steps=18,reward=-18
# Episode 9613: steps=15,reward=-15
# Episode 9614: steps=15,reward=-15
# Episode 9615: steps=19,reward=-19
# Episode 9616: steps=19,reward=-19
# Episode 9617: steps=19,reward=-19
# Episode 9618: steps=15,reward=-15
# Episode 9619: steps=15,reward=-15
# Episode 9620: steps=15,reward=-15
# Episode 9621: steps=15,reward=-15
# Episode 9622: steps=25,reward=-25
# Episode 9623: steps=20,reward=-119
# Episode 9624: steps=17,reward=-17
# Episode 9625: steps=15,reward=-15
# Episode 9626: steps=15,reward=-15
# Episode 9627: steps=19,reward=-19
# Episode 9628: steps=15,reward=-15
# Episode 9629: steps=17,reward=-17
# Episode 9630: steps=15,reward=-15
# Episode 9631: steps=17,reward=-17
# Episode 9632: steps=15,reward=-15
# Episode 9633: steps=15,reward=-15
# Episode 9634: steps=19,reward=-118
# Episode 9635: steps=18,reward=-18
# Episode 9636: steps=19,reward=-19
# Episode 9637: steps=17,reward=-17
# Episode 9638: steps=18,reward=-18
# Episode 9639: steps=17,reward=-17
# Episode 9640: steps=15,reward=-15
# Episode 9641: steps=20,reward=-20
# Episode 9642: steps=21,reward=-21
# Episode 9643: steps=15,reward=-15
# Episode 9644: steps=15,reward=-15
# Episode 9645: steps=15,reward=-15
# Episode 9646: steps=16,reward=-16
# Episode 9647: steps=15,reward=-15
# Episode 9648: steps=17,reward=-17
# Episode 9649: steps=17,reward=-17
# Episode 9650: steps=23,reward=-122
# Episode 9651: steps=15,reward=-15
# Episode 9652: steps=17,reward=-17
# Episode 9653: steps=16,reward=-16
# Episode 9654: steps=15,reward=-15
# Episode 9655: steps=20,reward=-20
# Episode 9656: steps=22,reward=-121
# Episode 9657: steps=17,reward=-17
# Episode 9658: steps=19,reward=-19
# Episode 9659: steps=17,reward=-17
# Episode 9660: steps=19,reward=-19
# Episode 9661: steps=17,reward=-17
# Episode 9662: steps=18,reward=-18
# Episode 9663: steps=15,reward=-15
# Episode 9664: steps=16,reward=-16
# Episode 9665: steps=20,reward=-20
# Episode 9666: steps=21,reward=-21
# Episode 9667: steps=17,reward=-17
# Episode 9668: steps=15,reward=-15
# Episode 9669: steps=21,reward=-21
# Episode 9670: steps=19,reward=-19
# Episode 9671: steps=15,reward=-15
# Episode 9672: steps=15,reward=-15
# Episode 9673: steps=23,reward=-122
# Episode 9674: steps=19,reward=-19
# Episode 9675: steps=19,reward=-19
# Episode 9676: steps=19,reward=-19
# Episode 9677: steps=18,reward=-18
# Episode 9678: steps=17,reward=-17
# Episode 9679: steps=17,reward=-17
# Episode 9680: steps=17,reward=-17
# Episode 9681: steps=17,reward=-17
# Episode 9682: steps=17,reward=-17
# Episode 9683: steps=20,reward=-20
# Episode 9684: steps=21,reward=-21
# Episode 9685: steps=20,reward=-20
# Episode 9686: steps=17,reward=-17
# Episode 9687: steps=19,reward=-19
# Episode 9688: steps=18,reward=-18
# Episode 9689: steps=21,reward=-21
# Episode 9690: steps=18,reward=-18
# Episode 9691: steps=17,reward=-17
# Episode 9692: steps=26,reward=-26
# Episode 9693: steps=17,reward=-17
# Episode 9694: steps=25,reward=-124
# Episode 9695: steps=17,reward=-17
# Episode 9696: steps=17,reward=-17
# Episode 9697: steps=17,reward=-17
# Episode 9698: steps=17,reward=-17
# Episode 9699: steps=17,reward=-17
# Episode 9700: steps=17,reward=-17
# Episode 9701: steps=19,reward=-19
# Episode 9702: steps=19,reward=-19
# Episode 9703: steps=17,reward=-17
# Episode 9704: steps=20,reward=-20
# Episode 9705: steps=17,reward=-17
# Episode 9706: steps=19,reward=-19
# Episode 9707: steps=17,reward=-17
# Episode 9708: steps=19,reward=-19
# Episode 9709: steps=25,reward=-25
# Episode 9710: steps=18,reward=-18
# Episode 9711: steps=21,reward=-21
# Episode 9712: steps=17,reward=-17
# Episode 9713: steps=20,reward=-20
# Episode 9714: steps=17,reward=-17
# Episode 9715: steps=19,reward=-19
# Episode 9716: steps=19,reward=-19
# Episode 9717: steps=19,reward=-19
# Episode 9718: steps=21,reward=-21
# Episode 9719: steps=20,reward=-20
# Episode 9720: steps=17,reward=-17
# Episode 9721: steps=19,reward=-19
# Episode 9722: steps=21,reward=-21
# Episode 9723: steps=18,reward=-18
# Episode 9724: steps=17,reward=-17
# Episode 9725: steps=21,reward=-21
# Episode 9726: steps=17,reward=-17
# Episode 9727: steps=21,reward=-21
# Episode 9728: steps=17,reward=-17
# Episode 9729: steps=18,reward=-18
# Episode 9730: steps=17,reward=-17
# Episode 9731: steps=19,reward=-19
# Episode 9732: steps=17,reward=-17
# Episode 9733: steps=21,reward=-21
# Episode 9734: steps=17,reward=-17
# Episode 9735: steps=17,reward=-17
# Episode 9736: steps=19,reward=-19
# Episode 9737: steps=19,reward=-19
# Episode 9738: steps=20,reward=-20
# Episode 9739: steps=17,reward=-17
# Episode 9740: steps=17,reward=-17
# Episode 9741: steps=17,reward=-17
# Episode 9742: steps=22,reward=-22
# Episode 9743: steps=19,reward=-19
# Episode 9744: steps=17,reward=-17
# Episode 9745: steps=17,reward=-17
# Episode 9746: steps=23,reward=-23
# Episode 9747: steps=17,reward=-17
# Episode 9748: steps=18,reward=-18
# Episode 9749: steps=19,reward=-19
# Episode 9750: steps=17,reward=-17
# Episode 9751: steps=17,reward=-17
# Episode 9752: steps=19,reward=-19
# Episode 9753: steps=18,reward=-18
# Episode 9754: steps=17,reward=-17
# Episode 9755: steps=15,reward=-15
# Episode 9756: steps=19,reward=-19
# Episode 9757: steps=17,reward=-17
# Episode 9758: steps=17,reward=-17
# Episode 9759: steps=21,reward=-21
# Episode 9760: steps=17,reward=-17
# Episode 9761: steps=17,reward=-17
# Episode 9762: steps=21,reward=-21
# Episode 9763: steps=23,reward=-23
# Episode 9764: steps=19,reward=-19
# Episode 9765: steps=17,reward=-17
# Episode 9766: steps=17,reward=-17
# Episode 9767: steps=17,reward=-17
# Episode 9768: steps=17,reward=-17
# Episode 9769: steps=17,reward=-17
# Episode 9770: steps=36,reward=-36
# Episode 9771: steps=17,reward=-17
# Episode 9772: steps=17,reward=-17
# Episode 9773: steps=17,reward=-17
# Episode 9774: steps=19,reward=-19
# Episode 9775: steps=17,reward=-17
# Episode 9776: steps=17,reward=-17
# Episode 9777: steps=15,reward=-15
# Episode 9778: steps=19,reward=-19
# Episode 9779: steps=21,reward=-21
# Episode 9780: steps=17,reward=-17
# Episode 9781: steps=19,reward=-19
# Episode 9782: steps=17,reward=-17
# Episode 9783: steps=17,reward=-17
# Episode 9784: steps=20,reward=-20
# Episode 9785: steps=18,reward=-18
# Episode 9786: steps=17,reward=-17
# Episode 9787: steps=17,reward=-17
# Episode 9788: steps=20,reward=-20
# Episode 9789: steps=19,reward=-19
# Episode 9790: steps=20,reward=-20
# Episode 9791: steps=17,reward=-17
# Episode 9792: steps=17,reward=-17
# Episode 9793: steps=19,reward=-19
# Episode 9794: steps=17,reward=-17
# Episode 9795: steps=17,reward=-17
# Episode 9796: steps=19,reward=-19
# Episode 9797: steps=17,reward=-17
# Episode 9798: steps=18,reward=-18
# Episode 9799: steps=15,reward=-15
# Episode 9800: steps=20,reward=-20
# Episode 9801: steps=23,reward=-122
# Episode 9802: steps=19,reward=-19
# Episode 9803: steps=17,reward=-17
# Episode 9804: steps=24,reward=-24
# Episode 9805: steps=19,reward=-19
# Episode 9806: steps=17,reward=-17
# Episode 9807: steps=19,reward=-19
# Episode 9808: steps=15,reward=-15
# Episode 9809: steps=15,reward=-15
# Episode 9810: steps=19,reward=-19
# Episode 9811: steps=15,reward=-15
# Episode 9812: steps=15,reward=-15
# Episode 9813: steps=20,reward=-20
# Episode 9814: steps=17,reward=-17
# Episode 9815: steps=15,reward=-15
# Episode 9816: steps=17,reward=-17
# Episode 9817: steps=15,reward=-15
# Episode 9818: steps=15,reward=-15
# Episode 9819: steps=15,reward=-15
# Episode 9820: steps=19,reward=-19
# Episode 9821: steps=15,reward=-15
# Episode 9822: steps=15,reward=-15
# Episode 9823: steps=15,reward=-15
# Episode 9824: steps=17,reward=-17
# Episode 9825: steps=15,reward=-15
# Episode 9826: steps=16,reward=-115
# Episode 9827: steps=15,reward=-15
# Episode 9828: steps=15,reward=-15
# Episode 9829: steps=17,reward=-17
# Episode 9830: steps=30,reward=-228
# Episode 9831: steps=15,reward=-15
# Episode 9832: steps=27,reward=-27
# Episode 9833: steps=19,reward=-19
# Episode 9834: steps=31,reward=-130
# Episode 9835: steps=15,reward=-15
# Episode 9836: steps=20,reward=-20
# Episode 9837: steps=16,reward=-16
# Episode 9838: steps=15,reward=-15
# Episode 9839: steps=17,reward=-17
# Episode 9840: steps=15,reward=-15
# Episode 9841: steps=16,reward=-16
# Episode 9842: steps=19,reward=-19
# Episode 9843: steps=15,reward=-15
# Episode 9844: steps=17,reward=-17
# Episode 9845: steps=15,reward=-15
# Episode 9846: steps=15,reward=-15
# Episode 9847: steps=24,reward=-24
# Episode 9848: steps=15,reward=-15
# Episode 9849: steps=60,reward=-258
# Episode 9850: steps=15,reward=-15
# Episode 9851: steps=15,reward=-15
# Episode 9852: steps=17,reward=-17
# Episode 9853: steps=17,reward=-17
# Episode 9854: steps=17,reward=-17
# Episode 9855: steps=17,reward=-17
# Episode 9856: steps=16,reward=-16
# Episode 9857: steps=15,reward=-15
# Episode 9858: steps=16,reward=-16
# Episode 9859: steps=17,reward=-17
# Episode 9860: steps=19,reward=-19
# Episode 9861: steps=17,reward=-17
# Episode 9862: steps=15,reward=-15
# Episode 9863: steps=19,reward=-19
# Episode 9864: steps=15,reward=-15
# Episode 9865: steps=18,reward=-18
# Episode 9866: steps=17,reward=-17
# Episode 9867: steps=20,reward=-20
# Episode 9868: steps=15,reward=-15
# Episode 9869: steps=15,reward=-15
# Episode 9870: steps=15,reward=-15
# Episode 9871: steps=17,reward=-17
# Episode 9872: steps=20,reward=-20
# Episode 9873: steps=15,reward=-15
# Episode 9874: steps=17,reward=-17
# Episode 9875: steps=15,reward=-15
# Episode 9876: steps=15,reward=-15
# Episode 9877: steps=15,reward=-15
# Episode 9878: steps=17,reward=-17
# Episode 9879: steps=15,reward=-15
# Episode 9880: steps=15,reward=-15
# Episode 9881: steps=15,reward=-15
# Episode 9882: steps=15,reward=-15
# Episode 9883: steps=15,reward=-15
# Episode 9884: steps=15,reward=-15
# Episode 9885: steps=20,reward=-20
# Episode 9886: steps=15,reward=-15
# Episode 9887: steps=17,reward=-17
# Episode 9888: steps=23,reward=-23
# Episode 9889: steps=15,reward=-15
# Episode 9890: steps=17,reward=-17
# Episode 9891: steps=16,reward=-115
# Episode 9892: steps=17,reward=-17
# Episode 9893: steps=21,reward=-120
# Episode 9894: steps=15,reward=-15
# Episode 9895: steps=15,reward=-15
# Episode 9896: steps=15,reward=-15
# Episode 9897: steps=15,reward=-15
# Episode 9898: steps=22,reward=-22
# Episode 9899: steps=15,reward=-15
# Episode 9900: steps=15,reward=-15
# Episode 9901: steps=17,reward=-17
# Episode 9902: steps=15,reward=-15
# Episode 9903: steps=15,reward=-15
# Episode 9904: steps=15,reward=-15
# Episode 9905: steps=17,reward=-17
# Episode 9906: steps=23,reward=-23
# Episode 9907: steps=21,reward=-21
# Episode 9908: steps=17,reward=-17
# Episode 9909: steps=17,reward=-17
# Episode 9910: steps=21,reward=-21
# Episode 9911: steps=19,reward=-19
# Episode 9912: steps=21,reward=-21
# Episode 9913: steps=17,reward=-17
# Episode 9914: steps=17,reward=-17
# Episode 9915: steps=24,reward=-24
# Episode 9916: steps=19,reward=-19
# Episode 9917: steps=17,reward=-17
# Episode 9918: steps=17,reward=-17
# Episode 9919: steps=21,reward=-21
# Episode 9920: steps=17,reward=-17
# Episode 9921: steps=18,reward=-18
# Episode 9922: steps=18,reward=-18
# Episode 9923: steps=19,reward=-19
# Episode 9924: steps=19,reward=-19
# Episode 9925: steps=17,reward=-17
# Episode 9926: steps=17,reward=-17
# Episode 9927: steps=21,reward=-21
# Episode 9928: steps=17,reward=-17
# Episode 9929: steps=17,reward=-17
# Episode 9930: steps=18,reward=-18
# Episode 9931: steps=17,reward=-17
# Episode 9932: steps=18,reward=-18
# Episode 9933: steps=17,reward=-17
# Episode 9934: steps=17,reward=-17
# Episode 9935: steps=17,reward=-17
# Episode 9936: steps=23,reward=-23
# Episode 9937: steps=20,reward=-20
# Episode 9938: steps=19,reward=-19
# Episode 9939: steps=19,reward=-19
# Episode 9940: steps=17,reward=-17
# Episode 9941: steps=17,reward=-17
# Episode 9942: steps=20,reward=-20
# Episode 9943: steps=20,reward=-20
# Episode 9944: steps=17,reward=-17
# Episode 9945: steps=18,reward=-18
# Episode 9946: steps=17,reward=-17
# Episode 9947: steps=21,reward=-21
# Episode 9948: steps=19,reward=-19
# Episode 9949: steps=17,reward=-17
# Episode 9950: steps=18,reward=-18
# Episode 9951: steps=20,reward=-119
# Episode 9952: steps=18,reward=-18
# Episode 9953: steps=17,reward=-17
# Episode 9954: steps=17,reward=-17
# Episode 9955: steps=19,reward=-19
# Episode 9956: steps=17,reward=-17
# Episode 9957: steps=19,reward=-19
# Episode 9958: steps=17,reward=-17
# Episode 9959: steps=20,reward=-119
# Episode 9960: steps=20,reward=-20
# Episode 9961: steps=18,reward=-18
# Episode 9962: steps=19,reward=-19
# Episode 9963: steps=19,reward=-19
# Episode 9964: steps=17,reward=-17
# Episode 9965: steps=18,reward=-18
# Episode 9966: steps=17,reward=-17
# Episode 9967: steps=18,reward=-18
# Episode 9968: steps=20,reward=-20
# Episode 9969: steps=19,reward=-19
# Episode 9970: steps=17,reward=-17
# Episode 9971: steps=19,reward=-19
# Episode 9972: steps=19,reward=-19
# Episode 9973: steps=17,reward=-17
# Episode 9974: steps=17,reward=-17
# Episode 9975: steps=18,reward=-18
# Episode 9976: steps=19,reward=-19
# Episode 9977: steps=18,reward=-117
# Episode 9978: steps=17,reward=-17
# Episode 9979: steps=17,reward=-17
# Episode 9980: steps=18,reward=-18
# Episode 9981: steps=18,reward=-18
# Episode 9982: steps=17,reward=-17
# Episode 9983: steps=17,reward=-17
# Episode 9984: steps=19,reward=-19
# Episode 9985: steps=17,reward=-17
# Episode 9986: steps=19,reward=-19
# Episode 9987: steps=17,reward=-17
# Episode 9988: steps=17,reward=-17
# Episode 9989: steps=17,reward=-17
# Episode 9990: steps=20,reward=-20
# Episode 9991: steps=18,reward=-18
# Episode 9992: steps=20,reward=-20
# Episode 9993: steps=17,reward=-17
# Episode 9994: steps=17,reward=-17
# Episode 9995: steps=17,reward=-17
# Episode 9996: steps=19,reward=-19
# Episode 9997: steps=18,reward=-18
# Episode 9998: steps=19,reward=-19
# Episode 9999: steps=17,reward=-17
# teset 0 reward = -17
# teset 1 reward = -17
# teset 2 reward = -17
# teset 3 reward = -17
# teset 4 reward = -17
# teset 5 reward = -17
# teset 6 reward = -17
# teset 7 reward = -17
# teset 8 reward = -17
# teset 9 reward = -17

# %%
#epsilon -= 0.01  ->  -13
agent.Q[24]
# Out:
# array([-7.18100419, -7.17570464, -7.19743283, -7.18179136])

# %%
#epsilon -= 0.001  ->  -13
agent.Q[24]
# Out:
# array([-7.17896399, -7.17570464, -7.20064965, -7.18710019])

# %%
#epsilon -= 0.0001  ->  -13
agent.Q[24]
# Out:
# array([-7.17955211, -7.17570464, -7.19729932, -7.21389891])

# %%
#epsilon -= 0.00001  ->  -13
agent.Q[24]
# Out:
# array([-7.18147152, -7.17570464, -7.20344373, -7.19425   ])

# %%
#epsilon -= 0.000001  ->  -15
agent.Q[24]

#引发一个问题 增加训练次数可以收敛吗(理论上)
# Out:
# array([ -7.71232075,  -8.52679442, -12.23321864,  -8.26062919])

# %%
#epsilon -= 0.0000001  ->  -17
agent.Q[24]
# Out:
# array([ -8.36048651, -11.47089318, -13.35743078,  -8.98157528])

# %%
import torch
torch.cuda.is_available()
# Out:
# False

# %%
import time
import numpy as np
import gymnasium as gym
class SarsaAgent(object):
    def __init__(self, obs_n,act_n,learning_rate=0.01,gamma=0.9,e_greedy=0.005):
        self.act_n=act_n
        self.lr=learning_rate
        self.gamma=gamma
        self.epsilon=e_greedy
        self.Q=np.zeros((obs_n,act_n))
       
    def sample(self,obs):
        if self.epsilon > 0: self.epsilon -= 0.0000001
        if np.random.uniform(0,1)<(1.0-self.epsilon):
            action=self.predict(obs)
        else:
            action=np.random.choice(self.act_n)
        return action
   
    def predict(self,obs):
        Q_list=self.Q[obs,:]
        maxQ=np.max(Q_list)
       
        action_list=np.where(Q_list==maxQ)[0]
        action=np.random.choice(action_list)
        return action
   
    def learn(self,obs,action,reward,next_obs,done):
        QList = self.Q[next_obs, :]
        Qmax = np.max(QList)
        predict_Q=self.Q[obs,action]
        if done:
            target_Q=reward
        else:
            target_Q=reward+self.gamma*Qmax
        self.Q[obs,action]=predict_Q+self.lr*(target_Q-predict_Q)
       
       
def run_episode(env,agent,render=False):
    total_steps=0
    total_reward=0
   
    obs=env.reset()[0]
    action=agent.sample(obs)
   
    while True:
        next_obs,reward,done,truncated,info=env.step(action)
        
       
        agent.learn(obs,action,reward,next_obs,done)
        next_action=agent.sample(next_obs)
        action=next_action
        obs=next_obs
       
        total_reward+=reward
        total_steps+=1
       
        if render:
            env.render()
       
        if done:
            break
       
    return total_reward, total_steps
   
def test_episode(env,agent):
    total_reward=0
    obs=env.reset()[0]
    #print(f"obs type: {type(obs)}, value: {obs}")
    while True:
        action=agent.predict(obs)
        next_obs,reward,done,tru,info=env.step(action)
        total_reward+=reward
        obs=next_obs
        time.sleep(0.1)
        env.render()
        if done:
            break
    return total_reward
def main():
    env=gym.make("CliffWalking-v0")
    agent=SarsaAgent(
            obs_n=env.observation_space.n,
            act_n=env.action_space.n,
            learning_rate=0.1,
            gamma=0.9,
            e_greedy=0.1)
    is_render=False
   
    for episode in range(10000):
        if episode == 10000:
            is_render = True
        ep_reward,ep_steps=run_episode(env,agent,is_render)
        print('Episode %s: steps=%s,reward=%.lf'%(episode,ep_steps,ep_reward))
       
       # if episode%20==0:
        #    is_render=True
        #else:
         #   is_render=False
           
           
    for episode in range(10):
        total_reward=test_episode(env,agent)
        print('teset %d reward = %.lf'%(episode,total_reward))
       
       
if __name__=='__main__':
    main()
# Out:
# Episode 0: steps=908,reward=-2294
# Episode 1: steps=124,reward=-124
# Episode 2: steps=374,reward=-869
# Episode 3: steps=335,reward=-830
# Episode 4: steps=253,reward=-352
# Episode 5: steps=61,reward=-61
# Episode 6: steps=294,reward=-492
# Episode 7: steps=59,reward=-59
# Episode 8: steps=225,reward=-225
# Episode 9: steps=71,reward=-71
# Episode 10: steps=196,reward=-295
# Episode 11: steps=142,reward=-142
# Episode 12: steps=112,reward=-310
# Episode 13: steps=99,reward=-99
# Episode 14: steps=49,reward=-49
# Episode 15: steps=91,reward=-91
# Episode 16: steps=164,reward=-263
# Episode 17: steps=73,reward=-73
# Episode 18: steps=139,reward=-238
# Episode 19: steps=149,reward=-248
# Episode 20: steps=76,reward=-175
# Episode 21: steps=87,reward=-87
# Episode 22: steps=91,reward=-91
# Episode 23: steps=123,reward=-123
# Episode 24: steps=56,reward=-56
# Episode 25: steps=290,reward=-686
# Episode 26: steps=114,reward=-213
# Episode 27: steps=59,reward=-158
# Episode 28: steps=63,reward=-162
# Episode 29: steps=121,reward=-121
# Episode 30: steps=46,reward=-46
# Episode 31: steps=22,reward=-22
# Episode 32: steps=94,reward=-193
# Episode 33: steps=90,reward=-90
# Episode 34: steps=56,reward=-56
# Episode 35: steps=136,reward=-334
# Episode 36: steps=103,reward=-202
# Episode 37: steps=46,reward=-46
# Episode 38: steps=59,reward=-59
# Episode 39: steps=93,reward=-93
# Episode 40: steps=88,reward=-286
# Episode 41: steps=81,reward=-180
# Episode 42: steps=51,reward=-51
# Episode 43: steps=45,reward=-45
# Episode 44: steps=76,reward=-76
# Episode 45: steps=19,reward=-19
# Episode 46: steps=50,reward=-50
# Episode 47: steps=77,reward=-77
# Episode 48: steps=85,reward=-283
# Episode 49: steps=129,reward=-327
# Episode 50: steps=47,reward=-47
# Episode 51: steps=50,reward=-50
# Episode 52: steps=37,reward=-37
# Episode 53: steps=91,reward=-190
# Episode 54: steps=45,reward=-45
# Episode 55: steps=33,reward=-33
# Episode 56: steps=46,reward=-46
# Episode 57: steps=70,reward=-70
# Episode 58: steps=55,reward=-55
# Episode 59: steps=41,reward=-41
# Episode 60: steps=51,reward=-51
# Episode 61: steps=30,reward=-30
# Episode 62: steps=21,reward=-21
# Episode 63: steps=78,reward=-78
# Episode 64: steps=28,reward=-28
# Episode 65: steps=58,reward=-58
# Episode 66: steps=46,reward=-145
# Episode 67: steps=47,reward=-47
# Episode 68: steps=34,reward=-34
# Episode 69: steps=57,reward=-156
# Episode 70: steps=35,reward=-35
# Episode 71: steps=43,reward=-43
# Episode 72: steps=20,reward=-20
# Episode 73: steps=76,reward=-76
# Episode 74: steps=32,reward=-32
# Episode 75: steps=41,reward=-41
# Episode 76: steps=42,reward=-42
# Episode 77: steps=31,reward=-31
# Episode 78: steps=65,reward=-65
# Episode 79: steps=45,reward=-144
# Episode 80: steps=35,reward=-35
# Episode 81: steps=44,reward=-44
# Episode 82: steps=28,reward=-28
# Episode 83: steps=106,reward=-304
# Episode 84: steps=32,reward=-32
# Episode 85: steps=44,reward=-44
# Episode 86: steps=55,reward=-55
# Episode 87: steps=45,reward=-45
# Episode 88: steps=48,reward=-147
# Episode 89: steps=42,reward=-42
# Episode 90: steps=30,reward=-30
# Episode 91: steps=35,reward=-233
# Episode 92: steps=25,reward=-25
# Episode 93: steps=27,reward=-27
# Episode 94: steps=70,reward=-169
# Episode 95: steps=45,reward=-45
# Episode 96: steps=37,reward=-37
# Episode 97: steps=57,reward=-255
# Episode 98: steps=37,reward=-136
# Episode 99: steps=36,reward=-36
# Episode 100: steps=41,reward=-41
# Episode 101: steps=41,reward=-140
# Episode 102: steps=74,reward=-272
# Episode 103: steps=32,reward=-32
# Episode 104: steps=40,reward=-40
# Episode 105: steps=80,reward=-179
# Episode 106: steps=31,reward=-31
# Episode 107: steps=31,reward=-130
# Episode 108: steps=22,reward=-22
# Episode 109: steps=23,reward=-23
# Episode 110: steps=35,reward=-35
# Episode 111: steps=34,reward=-133
# Episode 112: steps=35,reward=-35
# Episode 113: steps=27,reward=-27
# Episode 114: steps=51,reward=-150
# Episode 115: steps=27,reward=-27
# Episode 116: steps=43,reward=-43
# Episode 117: steps=28,reward=-28
# Episode 118: steps=23,reward=-23
# Episode 119: steps=37,reward=-136
# Episode 120: steps=39,reward=-39
# Episode 121: steps=20,reward=-20
# Episode 122: steps=29,reward=-29
# Episode 123: steps=20,reward=-20
# Episode 124: steps=53,reward=-53
# Episode 125: steps=45,reward=-243
# Episode 126: steps=64,reward=-163
# Episode 127: steps=22,reward=-22
# Episode 128: steps=37,reward=-37
# Episode 129: steps=19,reward=-19
# Episode 130: steps=25,reward=-25
# Episode 131: steps=35,reward=-35
# Episode 132: steps=25,reward=-25
# Episode 133: steps=24,reward=-24
# Episode 134: steps=17,reward=-17
# Episode 135: steps=28,reward=-28
# Episode 136: steps=62,reward=-260
# Episode 137: steps=17,reward=-17
# Episode 138: steps=29,reward=-29
# Episode 139: steps=35,reward=-35
# Episode 140: steps=25,reward=-25
# Episode 141: steps=14,reward=-14
# Episode 142: steps=38,reward=-38
# Episode 143: steps=22,reward=-121
# Episode 144: steps=30,reward=-30
# Episode 145: steps=25,reward=-25
# Episode 146: steps=38,reward=-137
# Episode 147: steps=13,reward=-13
# Episode 148: steps=31,reward=-31
# Episode 149: steps=34,reward=-34
# Episode 150: steps=28,reward=-28
# Episode 151: steps=42,reward=-42
# Episode 152: steps=24,reward=-123
# Episode 153: steps=34,reward=-133
# Episode 154: steps=31,reward=-31
# Episode 155: steps=23,reward=-23
# Episode 156: steps=20,reward=-20
# Episode 157: steps=27,reward=-27
# Episode 158: steps=23,reward=-23
# Episode 159: steps=32,reward=-32
# Episode 160: steps=19,reward=-19
# Episode 161: steps=23,reward=-23
# Episode 162: steps=21,reward=-21
# Episode 163: steps=26,reward=-26
# Episode 164: steps=15,reward=-15
# Episode 165: steps=16,reward=-16
# Episode 166: steps=28,reward=-28
# Episode 167: steps=25,reward=-25
# Episode 168: steps=44,reward=-143
# Episode 169: steps=30,reward=-30
# Episode 170: steps=17,reward=-17
# Episode 171: steps=29,reward=-29
# Episode 172: steps=24,reward=-24
# Episode 173: steps=22,reward=-22
# Episode 174: steps=22,reward=-22
# Episode 175: steps=26,reward=-26
# Episode 176: steps=17,reward=-17
# Episode 177: steps=19,reward=-19
# Episode 178: steps=32,reward=-32
# Episode 179: steps=41,reward=-140
# Episode 180: steps=13,reward=-13
# Episode 181: steps=33,reward=-33
# Episode 182: steps=17,reward=-17
# Episode 183: steps=34,reward=-34
# Episode 184: steps=19,reward=-19
# Episode 185: steps=30,reward=-327
# Episode 186: steps=29,reward=-29
# Episode 187: steps=35,reward=-35
# Episode 188: steps=13,reward=-13
# Episode 189: steps=38,reward=-38
# Episode 190: steps=23,reward=-23
# Episode 191: steps=15,reward=-15
# Episode 192: steps=19,reward=-19
# Episode 193: steps=22,reward=-22
# Episode 194: steps=20,reward=-20
# Episode 195: steps=28,reward=-28
# Episode 196: steps=33,reward=-33
# Episode 197: steps=15,reward=-15
# Episode 198: steps=17,reward=-17
# Episode 199: steps=26,reward=-125
# Episode 200: steps=36,reward=-135
# Episode 201: steps=19,reward=-19
# Episode 202: steps=24,reward=-24
# Episode 203: steps=23,reward=-23
# Episode 204: steps=13,reward=-13
# Episode 205: steps=20,reward=-20
# Episode 206: steps=61,reward=-358
# Episode 207: steps=21,reward=-21
# Episode 208: steps=17,reward=-17
# Episode 209: steps=26,reward=-26
# Episode 210: steps=27,reward=-27
# Episode 211: steps=17,reward=-17
# Episode 212: steps=31,reward=-130
# Episode 213: steps=29,reward=-128
# Episode 214: steps=32,reward=-131
# Episode 215: steps=22,reward=-22
# Episode 216: steps=13,reward=-13
# Episode 217: steps=15,reward=-15
# Episode 218: steps=17,reward=-17
# Episode 219: steps=54,reward=-252
# Episode 220: steps=26,reward=-26
# Episode 221: steps=13,reward=-13
# Episode 222: steps=21,reward=-21
# Episode 223: steps=42,reward=-141
# Episode 224: steps=32,reward=-32
# Episode 225: steps=28,reward=-127
# Episode 226: steps=17,reward=-17
# Episode 227: steps=13,reward=-13
# Episode 228: steps=15,reward=-15
# Episode 229: steps=31,reward=-130
# Episode 230: steps=34,reward=-232
# Episode 231: steps=30,reward=-30
# Episode 232: steps=13,reward=-13
# Episode 233: steps=15,reward=-15
# Episode 234: steps=22,reward=-22
# Episode 235: steps=28,reward=-226
# Episode 236: steps=31,reward=-31
# Episode 237: steps=15,reward=-15
# Episode 238: steps=14,reward=-14
# Episode 239: steps=39,reward=-138
# Episode 240: steps=20,reward=-20
# Episode 241: steps=17,reward=-17
# Episode 242: steps=15,reward=-15
# Episode 243: steps=14,reward=-14
# Episode 244: steps=28,reward=-28
# Episode 245: steps=19,reward=-19
# Episode 246: steps=27,reward=-126
# Episode 247: steps=13,reward=-13
# Episode 248: steps=28,reward=-28
# Episode 249: steps=28,reward=-127
# Episode 250: steps=13,reward=-13
# Episode 251: steps=13,reward=-13
# Episode 252: steps=17,reward=-17
# Episode 253: steps=15,reward=-15
# Episode 254: steps=13,reward=-13
# Episode 255: steps=37,reward=-136
# Episode 256: steps=29,reward=-29
# Episode 257: steps=24,reward=-123
# Episode 258: steps=17,reward=-17
# Episode 259: steps=17,reward=-17
# Episode 260: steps=13,reward=-13
# Episode 261: steps=23,reward=-23
# Episode 262: steps=15,reward=-15
# Episode 263: steps=14,reward=-14
# Episode 264: steps=29,reward=-128
# Episode 265: steps=30,reward=-30
# Episode 266: steps=16,reward=-16
# Episode 267: steps=28,reward=-127
# Episode 268: steps=17,reward=-17
# Episode 269: steps=19,reward=-118
# Episode 270: steps=29,reward=-326
# Episode 271: steps=35,reward=-134
# Episode 272: steps=24,reward=-24
# Episode 273: steps=31,reward=-229
# Episode 274: steps=21,reward=-21
# Episode 275: steps=17,reward=-17
# Episode 276: steps=15,reward=-15
# Episode 277: steps=13,reward=-13
# Episode 278: steps=13,reward=-13
# Episode 279: steps=18,reward=-18
# Episode 280: steps=18,reward=-18
# Episode 281: steps=13,reward=-13
# Episode 282: steps=18,reward=-117
# Episode 283: steps=15,reward=-15
# Episode 284: steps=24,reward=-24
# Episode 285: steps=25,reward=-124
# Episode 286: steps=13,reward=-13
# Episode 287: steps=13,reward=-13
# Episode 288: steps=20,reward=-119
# Episode 289: steps=15,reward=-15
# Episode 290: steps=16,reward=-115
# Episode 291: steps=13,reward=-13
# Episode 292: steps=13,reward=-13
# Episode 293: steps=13,reward=-13
# Episode 294: steps=29,reward=-227
# Episode 295: steps=17,reward=-17
# Episode 296: steps=13,reward=-13
# Episode 297: steps=13,reward=-13
# Episode 298: steps=17,reward=-17
# Episode 299: steps=24,reward=-123
# Episode 300: steps=13,reward=-13
# Episode 301: steps=13,reward=-13
# Episode 302: steps=25,reward=-223
# Episode 303: steps=13,reward=-13
# Episode 304: steps=13,reward=-13
# Episode 305: steps=14,reward=-14
# Episode 306: steps=13,reward=-13
# Episode 307: steps=24,reward=-24
# Episode 308: steps=15,reward=-15
# Episode 309: steps=17,reward=-17
# Episode 310: steps=32,reward=-230
# Episode 311: steps=20,reward=-20
# Episode 312: steps=13,reward=-13
# Episode 313: steps=13,reward=-13
# Episode 314: steps=15,reward=-15
# Episode 315: steps=27,reward=-126
# Episode 316: steps=22,reward=-121
# Episode 317: steps=13,reward=-13
# Episode 318: steps=13,reward=-13
# Episode 319: steps=20,reward=-119
# Episode 320: steps=30,reward=-228
# Episode 321: steps=15,reward=-15
# Episode 322: steps=13,reward=-13
# Episode 323: steps=24,reward=-123
# Episode 324: steps=18,reward=-18
# Episode 325: steps=13,reward=-13
# Episode 326: steps=25,reward=-223
# Episode 327: steps=15,reward=-15
# Episode 328: steps=13,reward=-13
# Episode 329: steps=15,reward=-15
# Episode 330: steps=15,reward=-15
# Episode 331: steps=13,reward=-13
# Episode 332: steps=13,reward=-13
# Episode 333: steps=13,reward=-13
# Episode 334: steps=13,reward=-13
# Episode 335: steps=13,reward=-13
# Episode 336: steps=15,reward=-15
# Episode 337: steps=13,reward=-13
# Episode 338: steps=26,reward=-125
# Episode 339: steps=29,reward=-128
# Episode 340: steps=15,reward=-15
# Episode 341: steps=15,reward=-15
# Episode 342: steps=13,reward=-13
# Episode 343: steps=22,reward=-121
# Episode 344: steps=22,reward=-22
# Episode 345: steps=20,reward=-119
# Episode 346: steps=18,reward=-18
# Episode 347: steps=23,reward=-221
# Episode 348: steps=31,reward=-229
# Episode 349: steps=15,reward=-15
# Episode 350: steps=19,reward=-19
# Episode 351: steps=13,reward=-13
# Episode 352: steps=17,reward=-17
# Episode 353: steps=19,reward=-19
# Episode 354: steps=13,reward=-13
# Episode 355: steps=17,reward=-116
# Episode 356: steps=29,reward=-128
# Episode 357: steps=19,reward=-19
# Episode 358: steps=25,reward=-124
# Episode 359: steps=37,reward=-334
# Episode 360: steps=13,reward=-13
# Episode 361: steps=19,reward=-19
# Episode 362: steps=13,reward=-13
# Episode 363: steps=15,reward=-15
# Episode 364: steps=13,reward=-13
# Episode 365: steps=15,reward=-15
# Episode 366: steps=13,reward=-13
# Episode 367: steps=13,reward=-13
# Episode 368: steps=17,reward=-17
# Episode 369: steps=13,reward=-13
# Episode 370: steps=14,reward=-14
# Episode 371: steps=39,reward=-138
# Episode 372: steps=14,reward=-14
# Episode 373: steps=15,reward=-15
# Episode 374: steps=13,reward=-13
# Episode 375: steps=15,reward=-15
# Episode 376: steps=55,reward=-550
# Episode 377: steps=13,reward=-13
# Episode 378: steps=13,reward=-13
# Episode 379: steps=15,reward=-15
# Episode 380: steps=13,reward=-13
# Episode 381: steps=27,reward=-126
# Episode 382: steps=24,reward=-123
# Episode 383: steps=18,reward=-117
# Episode 384: steps=15,reward=-15
# Episode 385: steps=15,reward=-15
# Episode 386: steps=21,reward=-21
# Episode 387: steps=13,reward=-13
# Episode 388: steps=13,reward=-13
# Episode 389: steps=15,reward=-15
# Episode 390: steps=15,reward=-15
# Episode 391: steps=17,reward=-17
# Episode 392: steps=13,reward=-13
# Episode 393: steps=15,reward=-15
# Episode 394: steps=32,reward=-230
# Episode 395: steps=15,reward=-15
# Episode 396: steps=41,reward=-239
# Episode 397: steps=13,reward=-13
# Episode 398: steps=41,reward=-338
# Episode 399: steps=13,reward=-13
# Episode 400: steps=13,reward=-13
# Episode 401: steps=13,reward=-13
# Episode 402: steps=13,reward=-13
# Episode 403: steps=15,reward=-15
# Episode 404: steps=15,reward=-15
# Episode 405: steps=15,reward=-15
# Episode 406: steps=13,reward=-13
# Episode 407: steps=20,reward=-119
# Episode 408: steps=13,reward=-13
# Episode 409: steps=15,reward=-15
# Episode 410: steps=17,reward=-116
# Episode 411: steps=15,reward=-15
# Episode 412: steps=13,reward=-13
# Episode 413: steps=15,reward=-15
# Episode 414: steps=15,reward=-15
# Episode 415: steps=17,reward=-17
# Episode 416: steps=15,reward=-15
# Episode 417: steps=16,reward=-16
# Episode 418: steps=29,reward=-227
# Episode 419: steps=13,reward=-13
# Episode 420: steps=22,reward=-22
# Episode 421: steps=25,reward=-124
# Episode 422: steps=13,reward=-13
# Episode 423: steps=16,reward=-16
# Episode 424: steps=19,reward=-19
# Episode 425: steps=19,reward=-118
# Episode 426: steps=13,reward=-13
# Episode 427: steps=30,reward=-30
# Episode 428: steps=15,reward=-15
# Episode 429: steps=14,reward=-14
# Episode 430: steps=21,reward=-120
# Episode 431: steps=13,reward=-13
# Episode 432: steps=13,reward=-13
# Episode 433: steps=27,reward=-126
# Episode 434: steps=15,reward=-15
# Episode 435: steps=14,reward=-14
# Episode 436: steps=18,reward=-18
# Episode 437: steps=23,reward=-23
# Episode 438: steps=32,reward=-131
# Episode 439: steps=15,reward=-15
# Episode 440: steps=14,reward=-14
# Episode 441: steps=20,reward=-119
# Episode 442: steps=14,reward=-14
# Episode 443: steps=18,reward=-18
# Episode 444: steps=14,reward=-14
# Episode 445: steps=13,reward=-13
# Episode 446: steps=13,reward=-13
# Episode 447: steps=15,reward=-15
# Episode 448: steps=13,reward=-13
# Episode 449: steps=13,reward=-13
# Episode 450: steps=17,reward=-17
# Episode 451: steps=13,reward=-13
# Episode 452: steps=15,reward=-15
# Episode 453: steps=17,reward=-116
# Episode 454: steps=13,reward=-13
# Episode 455: steps=26,reward=-125
# Episode 456: steps=18,reward=-18
# Episode 457: steps=15,reward=-15
# Episode 458: steps=13,reward=-13
# Episode 459: steps=13,reward=-13
# Episode 460: steps=13,reward=-13
# Episode 461: steps=13,reward=-13
# Episode 462: steps=13,reward=-13
# Episode 463: steps=22,reward=-220
# Episode 464: steps=15,reward=-15
# Episode 465: steps=13,reward=-13
# Episode 466: steps=13,reward=-13
# Episode 467: steps=13,reward=-13
# Episode 468: steps=15,reward=-15
# Episode 469: steps=14,reward=-14
# Episode 470: steps=15,reward=-15
# Episode 471: steps=15,reward=-15
# Episode 472: steps=19,reward=-118
# Episode 473: steps=14,reward=-14
# Episode 474: steps=30,reward=-129
# Episode 475: steps=15,reward=-15
# Episode 476: steps=13,reward=-13
# Episode 477: steps=26,reward=-26
# Episode 478: steps=15,reward=-15
# Episode 479: steps=15,reward=-15
# Episode 480: steps=15,reward=-15
# Episode 481: steps=26,reward=-125
# Episode 482: steps=17,reward=-17
# Episode 483: steps=19,reward=-19
# Episode 484: steps=13,reward=-13
# Episode 485: steps=13,reward=-13
# Episode 486: steps=19,reward=-19
# Episode 487: steps=13,reward=-13
# Episode 488: steps=27,reward=-126
# Episode 489: steps=15,reward=-15
# Episode 490: steps=15,reward=-15
# Episode 491: steps=15,reward=-15
# Episode 492: steps=16,reward=-16
# Episode 493: steps=17,reward=-17
# Episode 494: steps=22,reward=-121
# Episode 495: steps=34,reward=-232
# Episode 496: steps=14,reward=-14
# Episode 497: steps=13,reward=-13
# Episode 498: steps=15,reward=-15
# Episode 499: steps=19,reward=-19
# Episode 500: steps=17,reward=-17
# Episode 501: steps=15,reward=-15
# Episode 502: steps=13,reward=-13
# Episode 503: steps=13,reward=-13
# Episode 504: steps=13,reward=-13
# Episode 505: steps=13,reward=-13
# Episode 506: steps=23,reward=-122
# Episode 507: steps=16,reward=-115
# Episode 508: steps=18,reward=-18
# Episode 509: steps=14,reward=-14
# Episode 510: steps=15,reward=-15
# Episode 511: steps=13,reward=-13
# Episode 512: steps=15,reward=-15
# Episode 513: steps=15,reward=-15
# Episode 514: steps=15,reward=-15
# Episode 515: steps=13,reward=-13
# Episode 516: steps=13,reward=-13
# Episode 517: steps=21,reward=-120
# Episode 518: steps=15,reward=-15
# Episode 519: steps=25,reward=-124
# Episode 520: steps=15,reward=-15
# Episode 521: steps=15,reward=-15
# Episode 522: steps=32,reward=-230
# Episode 523: steps=15,reward=-15
# Episode 524: steps=13,reward=-13
# Episode 525: steps=23,reward=-23
# Episode 526: steps=25,reward=-25
# Episode 527: steps=18,reward=-18
# Episode 528: steps=25,reward=-25
# Episode 529: steps=15,reward=-15
# Episode 530: steps=14,reward=-14
# Episode 531: steps=14,reward=-14
# Episode 532: steps=15,reward=-15
# Episode 533: steps=17,reward=-17
# Episode 534: steps=13,reward=-13
# Episode 535: steps=20,reward=-20
# Episode 536: steps=17,reward=-17
# Episode 537: steps=15,reward=-15
# Episode 538: steps=13,reward=-13
# Episode 539: steps=16,reward=-16
# Episode 540: steps=13,reward=-13
# Episode 541: steps=13,reward=-13
# Episode 542: steps=25,reward=-25
# Episode 543: steps=30,reward=-129
# Episode 544: steps=13,reward=-13
# Episode 545: steps=13,reward=-13
# Episode 546: steps=17,reward=-17
# Episode 547: steps=13,reward=-13
# Episode 548: steps=13,reward=-13
# Episode 549: steps=15,reward=-15
# Episode 550: steps=15,reward=-15
# Episode 551: steps=15,reward=-15
# Episode 552: steps=15,reward=-15
# Episode 553: steps=13,reward=-13
# Episode 554: steps=13,reward=-13
# Episode 555: steps=13,reward=-13
# Episode 556: steps=13,reward=-13
# Episode 557: steps=13,reward=-13
# Episode 558: steps=15,reward=-15
# Episode 559: steps=13,reward=-13
# Episode 560: steps=13,reward=-13
# Episode 561: steps=15,reward=-15
# Episode 562: steps=13,reward=-13
# Episode 563: steps=13,reward=-13
# Episode 564: steps=19,reward=-118
# Episode 565: steps=34,reward=-232
# Episode 566: steps=13,reward=-13
# Episode 567: steps=13,reward=-13
# Episode 568: steps=13,reward=-13
# Episode 569: steps=15,reward=-15
# Episode 570: steps=13,reward=-13
# Episode 571: steps=15,reward=-15
# Episode 572: steps=15,reward=-15
# Episode 573: steps=13,reward=-13
# Episode 574: steps=30,reward=-129
# Episode 575: steps=24,reward=-123
# Episode 576: steps=13,reward=-13
# Episode 577: steps=15,reward=-15
# Episode 578: steps=15,reward=-15
# Episode 579: steps=13,reward=-13
# Episode 580: steps=14,reward=-14
# Episode 581: steps=13,reward=-13
# Episode 582: steps=14,reward=-14
# Episode 583: steps=20,reward=-20
# Episode 584: steps=13,reward=-13
# Episode 585: steps=13,reward=-13
# Episode 586: steps=13,reward=-13
# Episode 587: steps=13,reward=-13
# Episode 588: steps=16,reward=-16
# Episode 589: steps=13,reward=-13
# Episode 590: steps=13,reward=-13
# Episode 591: steps=13,reward=-13
# Episode 592: steps=20,reward=-20
# Episode 593: steps=14,reward=-14
# Episode 594: steps=28,reward=-226
# Episode 595: steps=15,reward=-15
# Episode 596: steps=38,reward=-236
# Episode 597: steps=13,reward=-13
# Episode 598: steps=13,reward=-13
# Episode 599: steps=13,reward=-13
# Episode 600: steps=17,reward=-116
# Episode 601: steps=13,reward=-13
# Episode 602: steps=17,reward=-116
# Episode 603: steps=13,reward=-13
# Episode 604: steps=17,reward=-17
# Episode 605: steps=13,reward=-13
# Episode 606: steps=13,reward=-13
# Episode 607: steps=19,reward=-19
# Episode 608: steps=13,reward=-13
# Episode 609: steps=22,reward=-121
# Episode 610: steps=13,reward=-13
# Episode 611: steps=13,reward=-13
# Episode 612: steps=13,reward=-13
# Episode 613: steps=29,reward=-128
# Episode 614: steps=16,reward=-16
# Episode 615: steps=13,reward=-13
# Episode 616: steps=15,reward=-15
# Episode 617: steps=15,reward=-15
# Episode 618: steps=13,reward=-13
# Episode 619: steps=17,reward=-116
# Episode 620: steps=13,reward=-13
# Episode 621: steps=13,reward=-13
# Episode 622: steps=15,reward=-15
# Episode 623: steps=13,reward=-13
# Episode 624: steps=15,reward=-15
# Episode 625: steps=32,reward=-230
# Episode 626: steps=14,reward=-14
# Episode 627: steps=13,reward=-13
# Episode 628: steps=23,reward=-221
# Episode 629: steps=14,reward=-113
# Episode 630: steps=36,reward=-234
# Episode 631: steps=15,reward=-15
# Episode 632: steps=21,reward=-21
# Episode 633: steps=13,reward=-13
# Episode 634: steps=21,reward=-21
# Episode 635: steps=13,reward=-13
# Episode 636: steps=20,reward=-119
# Episode 637: steps=16,reward=-115
# Episode 638: steps=22,reward=-22
# Episode 639: steps=19,reward=-19
# Episode 640: steps=19,reward=-118
# Episode 641: steps=13,reward=-13
# Episode 642: steps=20,reward=-119
# Episode 643: steps=21,reward=-120
# Episode 644: steps=13,reward=-13
# Episode 645: steps=15,reward=-15
# Episode 646: steps=15,reward=-15
# Episode 647: steps=15,reward=-15
# Episode 648: steps=13,reward=-13
# Episode 649: steps=22,reward=-121
# Episode 650: steps=13,reward=-13
# Episode 651: steps=15,reward=-15
# Episode 652: steps=13,reward=-13
# Episode 653: steps=15,reward=-15
# Episode 654: steps=18,reward=-117
# Episode 655: steps=20,reward=-119
# Episode 656: steps=13,reward=-13
# Episode 657: steps=25,reward=-223
# Episode 658: steps=31,reward=-130
# Episode 659: steps=13,reward=-13
# Episode 660: steps=13,reward=-13
# Episode 661: steps=24,reward=-24
# Episode 662: steps=13,reward=-13
# Episode 663: steps=13,reward=-13
# Episode 664: steps=13,reward=-13
# Episode 665: steps=13,reward=-13
# Episode 666: steps=29,reward=-128
# Episode 667: steps=25,reward=-124
# Episode 668: steps=15,reward=-15
# Episode 669: steps=27,reward=-126
# Episode 670: steps=13,reward=-13
# Episode 671: steps=30,reward=-30
# Episode 672: steps=13,reward=-13
# Episode 673: steps=24,reward=-222
# Episode 674: steps=14,reward=-14
# Episode 675: steps=13,reward=-13
# Episode 676: steps=14,reward=-14
# Episode 677: steps=13,reward=-13
# Episode 678: steps=13,reward=-13
# Episode 679: steps=21,reward=-219
# Episode 680: steps=15,reward=-15
# Episode 681: steps=26,reward=-26
# Episode 682: steps=33,reward=-132
# Episode 683: steps=13,reward=-13
# Episode 684: steps=15,reward=-15
# Episode 685: steps=37,reward=-235
# Episode 686: steps=13,reward=-13
# Episode 687: steps=19,reward=-118
# Episode 688: steps=14,reward=-14
# Episode 689: steps=13,reward=-13
# Episode 690: steps=13,reward=-13
# Episode 691: steps=19,reward=-19
# Episode 692: steps=15,reward=-15
# Episode 693: steps=13,reward=-13
# Episode 694: steps=23,reward=-122
# Episode 695: steps=18,reward=-18
# Episode 696: steps=18,reward=-18
# Episode 697: steps=15,reward=-15
# Episode 698: steps=15,reward=-15
# Episode 699: steps=15,reward=-15
# Episode 700: steps=24,reward=-123
# Episode 701: steps=26,reward=-224
# Episode 702: steps=13,reward=-13
# Episode 703: steps=15,reward=-15
# Episode 704: steps=26,reward=-26
# Episode 705: steps=21,reward=-120
# Episode 706: steps=15,reward=-15
# Episode 707: steps=19,reward=-19
# Episode 708: steps=29,reward=-128
# Episode 709: steps=17,reward=-17
# Episode 710: steps=13,reward=-13
# Episode 711: steps=17,reward=-17
# Episode 712: steps=13,reward=-13
# Episode 713: steps=14,reward=-14
# Episode 714: steps=17,reward=-17
# Episode 715: steps=21,reward=-120
# Episode 716: steps=13,reward=-13
# Episode 717: steps=18,reward=-117
# Episode 718: steps=17,reward=-17
# Episode 719: steps=14,reward=-113
# Episode 720: steps=47,reward=-245
# Episode 721: steps=13,reward=-13
# Episode 722: steps=13,reward=-13
# Episode 723: steps=13,reward=-13
# Episode 724: steps=20,reward=-20
# Episode 725: steps=13,reward=-13
# Episode 726: steps=23,reward=-122
# Episode 727: steps=15,reward=-15
# Episode 728: steps=16,reward=-115
# Episode 729: steps=13,reward=-13
# Episode 730: steps=19,reward=-19
# Episode 731: steps=18,reward=-117
# Episode 732: steps=25,reward=-124
# Episode 733: steps=18,reward=-117
# Episode 734: steps=17,reward=-17
# Episode 735: steps=15,reward=-15
# Episode 736: steps=19,reward=-118
# Episode 737: steps=13,reward=-13
# Episode 738: steps=21,reward=-120
# Episode 739: steps=13,reward=-13
# Episode 740: steps=18,reward=-18
# Episode 741: steps=26,reward=-224
# Episode 742: steps=13,reward=-13
# Episode 743: steps=13,reward=-13
# Episode 744: steps=28,reward=-127
# Episode 745: steps=22,reward=-121
# Episode 746: steps=25,reward=-124
# Episode 747: steps=17,reward=-17
# Episode 748: steps=13,reward=-13
# Episode 749: steps=16,reward=-115
# Episode 750: steps=13,reward=-13
# Episode 751: steps=20,reward=-119
# Episode 752: steps=14,reward=-14
# Episode 753: steps=28,reward=-226
# Episode 754: steps=19,reward=-19
# Episode 755: steps=13,reward=-13
# Episode 756: steps=15,reward=-15
# Episode 757: steps=14,reward=-14
# Episode 758: steps=27,reward=-126
# Episode 759: steps=15,reward=-15
# Episode 760: steps=31,reward=-229
# Episode 761: steps=15,reward=-15
# Episode 762: steps=13,reward=-13
# Episode 763: steps=21,reward=-120
# Episode 764: steps=18,reward=-18
# Episode 765: steps=19,reward=-19
# Episode 766: steps=13,reward=-13
# Episode 767: steps=38,reward=-137
# Episode 768: steps=17,reward=-17
# Episode 769: steps=13,reward=-13
# Episode 770: steps=28,reward=-127
# Episode 771: steps=13,reward=-13
# Episode 772: steps=16,reward=-16
# Episode 773: steps=15,reward=-15
# Episode 774: steps=17,reward=-17
# Episode 775: steps=16,reward=-115
# Episode 776: steps=13,reward=-13
# Episode 777: steps=23,reward=-122
# Episode 778: steps=13,reward=-13
# Episode 779: steps=20,reward=-119
# Episode 780: steps=15,reward=-15
# Episode 781: steps=17,reward=-17
# Episode 782: steps=13,reward=-13
# Episode 783: steps=16,reward=-16
# Episode 784: steps=13,reward=-13
# Episode 785: steps=15,reward=-15
# Episode 786: steps=13,reward=-13
# Episode 787: steps=13,reward=-13
# Episode 788: steps=18,reward=-18
# Episode 789: steps=13,reward=-13
# Episode 790: steps=17,reward=-17
# Episode 791: steps=13,reward=-13
# Episode 792: steps=13,reward=-13
# Episode 793: steps=18,reward=-117
# Episode 794: steps=13,reward=-13
# Episode 795: steps=13,reward=-13
# Episode 796: steps=17,reward=-116
# Episode 797: steps=15,reward=-15
# Episode 798: steps=13,reward=-13
# Episode 799: steps=23,reward=-122
# Episode 800: steps=15,reward=-15
# Episode 801: steps=23,reward=-122
# Episode 802: steps=23,reward=-23
# Episode 803: steps=16,reward=-115
# Episode 804: steps=15,reward=-15
# Episode 805: steps=15,reward=-114
# Episode 806: steps=13,reward=-13
# Episode 807: steps=23,reward=-122
# Episode 808: steps=15,reward=-15
# Episode 809: steps=13,reward=-13
# Episode 810: steps=13,reward=-13
# Episode 811: steps=15,reward=-15
# Episode 812: steps=15,reward=-15
# Episode 813: steps=13,reward=-13
# Episode 814: steps=15,reward=-15
# Episode 815: steps=13,reward=-13
# Episode 816: steps=13,reward=-13
# Episode 817: steps=15,reward=-15
# Episode 818: steps=20,reward=-119
# Episode 819: steps=13,reward=-13
# Episode 820: steps=15,reward=-15
# Episode 821: steps=13,reward=-13
# Episode 822: steps=13,reward=-13
# Episode 823: steps=13,reward=-13
# Episode 824: steps=18,reward=-117
# Episode 825: steps=27,reward=-126
# Episode 826: steps=17,reward=-17
# Episode 827: steps=26,reward=-125
# Episode 828: steps=16,reward=-16
# Episode 829: steps=17,reward=-17
# Episode 830: steps=13,reward=-13
# Episode 831: steps=23,reward=-122
# Episode 832: steps=13,reward=-13
# Episode 833: steps=13,reward=-13
# Episode 834: steps=14,reward=-14
# Episode 835: steps=23,reward=-122
# Episode 836: steps=20,reward=-20
# Episode 837: steps=15,reward=-15
# Episode 838: steps=29,reward=-128
# Episode 839: steps=14,reward=-14
# Episode 840: steps=29,reward=-227
# Episode 841: steps=13,reward=-13
# Episode 842: steps=15,reward=-15
# Episode 843: steps=15,reward=-15
# Episode 844: steps=13,reward=-13
# Episode 845: steps=13,reward=-13
# Episode 846: steps=15,reward=-15
# Episode 847: steps=19,reward=-118
# Episode 848: steps=15,reward=-15
# Episode 849: steps=15,reward=-15
# Episode 850: steps=22,reward=-121
# Episode 851: steps=24,reward=-123
# Episode 852: steps=15,reward=-15
# Episode 853: steps=15,reward=-15
# Episode 854: steps=24,reward=-123
# Episode 855: steps=15,reward=-15
# Episode 856: steps=26,reward=-224
# Episode 857: steps=21,reward=-21
# Episode 858: steps=13,reward=-13
# Episode 859: steps=26,reward=-125
# Episode 860: steps=13,reward=-13
# Episode 861: steps=19,reward=-19
# Episode 862: steps=13,reward=-13
# Episode 863: steps=15,reward=-15
# Episode 864: steps=29,reward=-227
# Episode 865: steps=27,reward=-27
# Episode 866: steps=14,reward=-14
# Episode 867: steps=53,reward=-449
# Episode 868: steps=25,reward=-124
# Episode 869: steps=15,reward=-15
# Episode 870: steps=19,reward=-118
# Episode 871: steps=13,reward=-13
# Episode 872: steps=15,reward=-15
# Episode 873: steps=13,reward=-13
# Episode 874: steps=15,reward=-15
# Episode 875: steps=19,reward=-19
# Episode 876: steps=15,reward=-15
# Episode 877: steps=13,reward=-13
# Episode 878: steps=19,reward=-19
# Episode 879: steps=13,reward=-13
# Episode 880: steps=13,reward=-13
# Episode 881: steps=17,reward=-17
# Episode 882: steps=13,reward=-13
# Episode 883: steps=20,reward=-119
# Episode 884: steps=19,reward=-118
# Episode 885: steps=24,reward=-123
# Episode 886: steps=16,reward=-16
# Episode 887: steps=17,reward=-17
# Episode 888: steps=15,reward=-15
# Episode 889: steps=17,reward=-17
# Episode 890: steps=13,reward=-13
# Episode 891: steps=13,reward=-13
# Episode 892: steps=25,reward=-124
# Episode 893: steps=27,reward=-225
# Episode 894: steps=17,reward=-17
# Episode 895: steps=26,reward=-224
# Episode 896: steps=15,reward=-15
# Episode 897: steps=19,reward=-118
# Episode 898: steps=14,reward=-14
# Episode 899: steps=15,reward=-15
# Episode 900: steps=14,reward=-113
# Episode 901: steps=13,reward=-13
# Episode 902: steps=15,reward=-15
# Episode 903: steps=15,reward=-15
# Episode 904: steps=14,reward=-14
# Episode 905: steps=37,reward=-334
# Episode 906: steps=15,reward=-15
# Episode 907: steps=15,reward=-15
# Episode 908: steps=34,reward=-232
# Episode 909: steps=13,reward=-13
# Episode 910: steps=17,reward=-17
# Episode 911: steps=15,reward=-15
# Episode 912: steps=15,reward=-15
# Episode 913: steps=13,reward=-13
# Episode 914: steps=13,reward=-13
# Episode 915: steps=15,reward=-15
# Episode 916: steps=15,reward=-15
# Episode 917: steps=15,reward=-15
# Episode 918: steps=15,reward=-15
# Episode 919: steps=39,reward=-237
# Episode 920: steps=15,reward=-15
# Episode 921: steps=15,reward=-15
# Episode 922: steps=13,reward=-13
# Episode 923: steps=16,reward=-115
# Episode 924: steps=13,reward=-13
# Episode 925: steps=13,reward=-13
# Episode 926: steps=13,reward=-13
# Episode 927: steps=21,reward=-120
# Episode 928: steps=13,reward=-13
# Episode 929: steps=13,reward=-13
# Episode 930: steps=24,reward=-24
# Episode 931: steps=14,reward=-14
# Episode 932: steps=17,reward=-17
# Episode 933: steps=15,reward=-15
# Episode 934: steps=15,reward=-15
# Episode 935: steps=15,reward=-15
# Episode 936: steps=13,reward=-13
# Episode 937: steps=13,reward=-13
# Episode 938: steps=13,reward=-13
# Episode 939: steps=14,reward=-14
# Episode 940: steps=15,reward=-15
# Episode 941: steps=15,reward=-15
# Episode 942: steps=13,reward=-13
# Episode 943: steps=19,reward=-118
# Episode 944: steps=18,reward=-18
# Episode 945: steps=22,reward=-121
# Episode 946: steps=13,reward=-13
# Episode 947: steps=18,reward=-117
# Episode 948: steps=17,reward=-17
# Episode 949: steps=13,reward=-13
# Episode 950: steps=15,reward=-15
# Episode 951: steps=33,reward=-231
# Episode 952: steps=28,reward=-28
# Episode 953: steps=13,reward=-13
# Episode 954: steps=21,reward=-120
# Episode 955: steps=13,reward=-13
# Episode 956: steps=18,reward=-18
# Episode 957: steps=13,reward=-13
# Episode 958: steps=13,reward=-13
# Episode 959: steps=35,reward=-233
# Episode 960: steps=15,reward=-15
# Episode 961: steps=29,reward=-227
# Episode 962: steps=13,reward=-13
# Episode 963: steps=26,reward=-125
# Episode 964: steps=13,reward=-13
# Episode 965: steps=13,reward=-13
# Episode 966: steps=13,reward=-13
# Episode 967: steps=15,reward=-15
# Episode 968: steps=13,reward=-13
# Episode 969: steps=16,reward=-16
# Episode 970: steps=13,reward=-13
# Episode 971: steps=15,reward=-15
# Episode 972: steps=17,reward=-17
# Episode 973: steps=23,reward=-122
# Episode 974: steps=13,reward=-13
# Episode 975: steps=15,reward=-15
# Episode 976: steps=15,reward=-15
# Episode 977: steps=13,reward=-13
# Episode 978: steps=18,reward=-18
# Episode 979: steps=15,reward=-15
# Episode 980: steps=13,reward=-13
# Episode 981: steps=15,reward=-15
# Episode 982: steps=13,reward=-13
# Episode 983: steps=29,reward=-326
# Episode 984: steps=27,reward=-225
# Episode 985: steps=13,reward=-13
# Episode 986: steps=24,reward=-123
# Episode 987: steps=20,reward=-119
# Episode 988: steps=15,reward=-15
# Episode 989: steps=13,reward=-13
# Episode 990: steps=15,reward=-15
# Episode 991: steps=25,reward=-124
# Episode 992: steps=15,reward=-15
# Episode 993: steps=26,reward=-125
# Episode 994: steps=22,reward=-121
# Episode 995: steps=24,reward=-123
# Episode 996: steps=21,reward=-219
# Episode 997: steps=17,reward=-17
# Episode 998: steps=17,reward=-17
# Episode 999: steps=15,reward=-15
# Episode 1000: steps=17,reward=-17
# Episode 1001: steps=26,reward=-125
# Episode 1002: steps=23,reward=-23
# Episode 1003: steps=13,reward=-13
# Episode 1004: steps=14,reward=-113
# Episode 1005: steps=15,reward=-15
# Episode 1006: steps=13,reward=-13
# Episode 1007: steps=13,reward=-13
# Episode 1008: steps=15,reward=-15
# Episode 1009: steps=15,reward=-15
# Episode 1010: steps=15,reward=-15
# Episode 1011: steps=15,reward=-114
# Episode 1012: steps=15,reward=-15
# Episode 1013: steps=27,reward=-126
# Episode 1014: steps=15,reward=-15
# Episode 1015: steps=13,reward=-13
# Episode 1016: steps=25,reward=-124
# Episode 1017: steps=30,reward=-327
# Episode 1018: steps=13,reward=-13
# Episode 1019: steps=15,reward=-15
# Episode 1020: steps=32,reward=-230
# Episode 1021: steps=15,reward=-15
# Episode 1022: steps=13,reward=-13
# Episode 1023: steps=34,reward=-331
# Episode 1024: steps=15,reward=-15
# Episode 1025: steps=13,reward=-13
# Episode 1026: steps=13,reward=-13
# Episode 1027: steps=13,reward=-13
# Episode 1028: steps=15,reward=-15
# Episode 1029: steps=17,reward=-17
# Episode 1030: steps=13,reward=-13
# Episode 1031: steps=15,reward=-15
# Episode 1032: steps=13,reward=-13
# Episode 1033: steps=13,reward=-13
# Episode 1034: steps=23,reward=-122
# Episode 1035: steps=15,reward=-15
# Episode 1036: steps=15,reward=-15
# Episode 1037: steps=13,reward=-13
# Episode 1038: steps=13,reward=-13
# Episode 1039: steps=13,reward=-13
# Episode 1040: steps=13,reward=-13
# Episode 1041: steps=18,reward=-18
# Episode 1042: steps=13,reward=-13
# Episode 1043: steps=15,reward=-15
# Episode 1044: steps=15,reward=-15
# Episode 1045: steps=13,reward=-13
# Episode 1046: steps=40,reward=-238
# Episode 1047: steps=13,reward=-13
# Episode 1048: steps=35,reward=-332
# Episode 1049: steps=13,reward=-13
# Episode 1050: steps=13,reward=-13
# Episode 1051: steps=13,reward=-13
# Episode 1052: steps=17,reward=-17
# Episode 1053: steps=16,reward=-16
# Episode 1054: steps=13,reward=-13
# Episode 1055: steps=13,reward=-13
# Episode 1056: steps=13,reward=-13
# Episode 1057: steps=15,reward=-15
# Episode 1058: steps=14,reward=-14
# Episode 1059: steps=15,reward=-15
# Episode 1060: steps=13,reward=-13
# Episode 1061: steps=27,reward=-126
# Episode 1062: steps=13,reward=-13
# Episode 1063: steps=13,reward=-13
# Episode 1064: steps=15,reward=-15
# Episode 1065: steps=13,reward=-13
# Episode 1066: steps=15,reward=-15
# Episode 1067: steps=14,reward=-113
# Episode 1068: steps=13,reward=-13
# Episode 1069: steps=13,reward=-13
# Episode 1070: steps=15,reward=-15
# Episode 1071: steps=14,reward=-14
# Episode 1072: steps=19,reward=-118
# Episode 1073: steps=15,reward=-15
# Episode 1074: steps=13,reward=-13
# Episode 1075: steps=15,reward=-15
# Episode 1076: steps=22,reward=-121
# Episode 1077: steps=13,reward=-13
# Episode 1078: steps=19,reward=-118
# Episode 1079: steps=24,reward=-123
# Episode 1080: steps=15,reward=-15
# Episode 1081: steps=13,reward=-13
# Episode 1082: steps=13,reward=-13
# Episode 1083: steps=13,reward=-13
# Episode 1084: steps=13,reward=-13
# Episode 1085: steps=15,reward=-15
# Episode 1086: steps=15,reward=-15
# Episode 1087: steps=15,reward=-15
# Episode 1088: steps=17,reward=-17
# Episode 1089: steps=19,reward=-19
# Episode 1090: steps=13,reward=-13
# Episode 1091: steps=15,reward=-15
# Episode 1092: steps=13,reward=-13
# Episode 1093: steps=16,reward=-115
# Episode 1094: steps=21,reward=-120
# Episode 1095: steps=25,reward=-124
# Episode 1096: steps=13,reward=-13
# Episode 1097: steps=15,reward=-15
# Episode 1098: steps=15,reward=-15
# Episode 1099: steps=18,reward=-18
# Episode 1100: steps=14,reward=-113
# Episode 1101: steps=18,reward=-117
# Episode 1102: steps=13,reward=-13
# Episode 1103: steps=13,reward=-13
# Episode 1104: steps=17,reward=-17
# Episode 1105: steps=13,reward=-13
# Episode 1106: steps=13,reward=-13
# Episode 1107: steps=20,reward=-119
# Episode 1108: steps=13,reward=-13
# Episode 1109: steps=15,reward=-15
# Episode 1110: steps=15,reward=-15
# Episode 1111: steps=19,reward=-118
# Episode 1112: steps=13,reward=-13
# Episode 1113: steps=13,reward=-13
# Episode 1114: steps=17,reward=-17
# Episode 1115: steps=13,reward=-13
# Episode 1116: steps=13,reward=-13
# Episode 1117: steps=13,reward=-13
# Episode 1118: steps=13,reward=-13
# Episode 1119: steps=24,reward=-222
# Episode 1120: steps=21,reward=-21
# Episode 1121: steps=15,reward=-15
# Episode 1122: steps=21,reward=-120
# Episode 1123: steps=13,reward=-13
# Episode 1124: steps=13,reward=-13
# Episode 1125: steps=13,reward=-13
# Episode 1126: steps=13,reward=-13
# Episode 1127: steps=28,reward=-226
# Episode 1128: steps=17,reward=-17
# Episode 1129: steps=17,reward=-17
# Episode 1130: steps=16,reward=-16
# Episode 1131: steps=15,reward=-15
# Episode 1132: steps=14,reward=-14
# Episode 1133: steps=13,reward=-13
# Episode 1134: steps=13,reward=-13
# Episode 1135: steps=13,reward=-13
# Episode 1136: steps=13,reward=-13
# Episode 1137: steps=15,reward=-15
# Episode 1138: steps=13,reward=-13
# Episode 1139: steps=13,reward=-13
# Episode 1140: steps=32,reward=-230
# Episode 1141: steps=16,reward=-115
# Episode 1142: steps=19,reward=-118
# Episode 1143: steps=17,reward=-17
# Episode 1144: steps=13,reward=-13
# Episode 1145: steps=15,reward=-15
# Episode 1146: steps=17,reward=-17
# Episode 1147: steps=20,reward=-119
# Episode 1148: steps=13,reward=-13
# Episode 1149: steps=15,reward=-15
# Episode 1150: steps=15,reward=-15
# Episode 1151: steps=15,reward=-15
# Episode 1152: steps=13,reward=-13
# Episode 1153: steps=13,reward=-13
# Episode 1154: steps=13,reward=-13
# Episode 1155: steps=13,reward=-13
# Episode 1156: steps=13,reward=-13
# Episode 1157: steps=13,reward=-13
# Episode 1158: steps=23,reward=-23
# Episode 1159: steps=13,reward=-13
# Episode 1160: steps=40,reward=-238
# Episode 1161: steps=15,reward=-15
# Episode 1162: steps=13,reward=-13
# Episode 1163: steps=13,reward=-13
# Episode 1164: steps=14,reward=-14
# Episode 1165: steps=22,reward=-121
# Episode 1166: steps=19,reward=-118
# Episode 1167: steps=13,reward=-13
# Episode 1168: steps=31,reward=-229
# Episode 1169: steps=32,reward=-230
# Episode 1170: steps=13,reward=-13
# Episode 1171: steps=15,reward=-15
# Episode 1172: steps=13,reward=-13
# Episode 1173: steps=13,reward=-13
# Episode 1174: steps=16,reward=-115
# Episode 1175: steps=15,reward=-15
# Episode 1176: steps=18,reward=-18
# Episode 1177: steps=13,reward=-13
# Episode 1178: steps=18,reward=-18
# Episode 1179: steps=15,reward=-15
# Episode 1180: steps=20,reward=-119
# Episode 1181: steps=18,reward=-117
# Episode 1182: steps=13,reward=-13
# Episode 1183: steps=13,reward=-13
# Episode 1184: steps=15,reward=-15
# Episode 1185: steps=13,reward=-13
# Episode 1186: steps=13,reward=-13
# Episode 1187: steps=17,reward=-116
# Episode 1188: steps=13,reward=-13
# Episode 1189: steps=16,reward=-115
# Episode 1190: steps=17,reward=-17
# Episode 1191: steps=17,reward=-17
# Episode 1192: steps=20,reward=-20
# Episode 1193: steps=14,reward=-14
# Episode 1194: steps=13,reward=-13
# Episode 1195: steps=17,reward=-116
# Episode 1196: steps=54,reward=-351
# Episode 1197: steps=15,reward=-15
# Episode 1198: steps=13,reward=-13
# Episode 1199: steps=13,reward=-13
# Episode 1200: steps=15,reward=-15
# Episode 1201: steps=25,reward=-124
# Episode 1202: steps=27,reward=-126
# Episode 1203: steps=13,reward=-13
# Episode 1204: steps=19,reward=-118
# Episode 1205: steps=29,reward=-227
# Episode 1206: steps=13,reward=-13
# Episode 1207: steps=13,reward=-13
# Episode 1208: steps=16,reward=-16
# Episode 1209: steps=20,reward=-218
# Episode 1210: steps=17,reward=-17
# Episode 1211: steps=13,reward=-13
# Episode 1212: steps=19,reward=-19
# Episode 1213: steps=13,reward=-13
# Episode 1214: steps=13,reward=-13
# Episode 1215: steps=15,reward=-15
# Episode 1216: steps=22,reward=-121
# Episode 1217: steps=15,reward=-15
# Episode 1218: steps=13,reward=-13
# Episode 1219: steps=13,reward=-13
# Episode 1220: steps=13,reward=-13
# Episode 1221: steps=15,reward=-15
# Episode 1222: steps=15,reward=-15
# Episode 1223: steps=17,reward=-17
# Episode 1224: steps=15,reward=-15
# Episode 1225: steps=15,reward=-15
# Episode 1226: steps=27,reward=-126
# Episode 1227: steps=20,reward=-119
# Episode 1228: steps=13,reward=-13
# Episode 1229: steps=30,reward=-129
# Episode 1230: steps=22,reward=-121
# Episode 1231: steps=19,reward=-118
# Episode 1232: steps=20,reward=-119
# Episode 1233: steps=13,reward=-13
# Episode 1234: steps=25,reward=-223
# Episode 1235: steps=57,reward=-453
# Episode 1236: steps=35,reward=-134
# Episode 1237: steps=13,reward=-13
# Episode 1238: steps=13,reward=-13
# Episode 1239: steps=27,reward=-324
# Episode 1240: steps=15,reward=-15
# Episode 1241: steps=36,reward=-234
# Episode 1242: steps=13,reward=-13
# Episode 1243: steps=13,reward=-13
# Episode 1244: steps=30,reward=-129
# Episode 1245: steps=13,reward=-13
# Episode 1246: steps=13,reward=-13
# Episode 1247: steps=24,reward=-123
# Episode 1248: steps=13,reward=-13
# Episode 1249: steps=15,reward=-15
# Episode 1250: steps=17,reward=-17
# Episode 1251: steps=15,reward=-15
# Episode 1252: steps=15,reward=-15
# Episode 1253: steps=13,reward=-13
# Episode 1254: steps=15,reward=-15
# Episode 1255: steps=21,reward=-120
# Episode 1256: steps=13,reward=-13
# Episode 1257: steps=13,reward=-13
# Episode 1258: steps=15,reward=-15
# Episode 1259: steps=21,reward=-21
# Episode 1260: steps=13,reward=-13
# Episode 1261: steps=17,reward=-116
# Episode 1262: steps=17,reward=-17
# Episode 1263: steps=13,reward=-13
# Episode 1264: steps=13,reward=-13
# Episode 1265: steps=42,reward=-240
# Episode 1266: steps=17,reward=-17
# Episode 1267: steps=13,reward=-13
# Episode 1268: steps=13,reward=-13
# Episode 1269: steps=13,reward=-13
# Episode 1270: steps=14,reward=-14
# Episode 1271: steps=16,reward=-16
# Episode 1272: steps=27,reward=-27
# Episode 1273: steps=13,reward=-13
# Episode 1274: steps=13,reward=-13
# Episode 1275: steps=27,reward=-126
# Episode 1276: steps=17,reward=-17
# Episode 1277: steps=14,reward=-14
# Episode 1278: steps=15,reward=-15
# Episode 1279: steps=20,reward=-119
# Episode 1280: steps=24,reward=-222
# Episode 1281: steps=14,reward=-14
# Episode 1282: steps=13,reward=-13
# Episode 1283: steps=17,reward=-17
# Episode 1284: steps=16,reward=-16
# Episode 1285: steps=13,reward=-13
# Episode 1286: steps=15,reward=-15
# Episode 1287: steps=20,reward=-20
# Episode 1288: steps=13,reward=-13
# Episode 1289: steps=13,reward=-13
# Episode 1290: steps=25,reward=-124
# Episode 1291: steps=13,reward=-13
# Episode 1292: steps=13,reward=-13
# Episode 1293: steps=19,reward=-19
# Episode 1294: steps=24,reward=-123
# Episode 1295: steps=38,reward=-335
# Episode 1296: steps=21,reward=-120
# Episode 1297: steps=27,reward=-225
# Episode 1298: steps=15,reward=-15
# Episode 1299: steps=13,reward=-13
# Episode 1300: steps=13,reward=-13
# Episode 1301: steps=27,reward=-27
# Episode 1302: steps=21,reward=-120
# Episode 1303: steps=17,reward=-17
# Episode 1304: steps=28,reward=-226
# Episode 1305: steps=17,reward=-17
# Episode 1306: steps=23,reward=-122
# Episode 1307: steps=21,reward=-120
# Episode 1308: steps=15,reward=-15
# Episode 1309: steps=13,reward=-13
# Episode 1310: steps=15,reward=-15
# Episode 1311: steps=23,reward=-122
# Episode 1312: steps=21,reward=-120
# Episode 1313: steps=25,reward=-124
# Episode 1314: steps=13,reward=-13
# Episode 1315: steps=22,reward=-220
# Episode 1316: steps=29,reward=-227
# Episode 1317: steps=13,reward=-13
# Episode 1318: steps=23,reward=-122
# Episode 1319: steps=13,reward=-13
# Episode 1320: steps=15,reward=-15
# Episode 1321: steps=13,reward=-13
# Episode 1322: steps=14,reward=-113
# Episode 1323: steps=14,reward=-14
# Episode 1324: steps=13,reward=-13
# Episode 1325: steps=23,reward=-122
# Episode 1326: steps=25,reward=-124
# Episode 1327: steps=13,reward=-13
# Episode 1328: steps=15,reward=-15
# Episode 1329: steps=15,reward=-15
# Episode 1330: steps=13,reward=-13
# Episode 1331: steps=22,reward=-121
# Episode 1332: steps=15,reward=-15
# Episode 1333: steps=20,reward=-119
# Episode 1334: steps=13,reward=-13
# Episode 1335: steps=15,reward=-15
# Episode 1336: steps=14,reward=-14
# Episode 1337: steps=13,reward=-13
# Episode 1338: steps=15,reward=-15
# Episode 1339: steps=15,reward=-15
# Episode 1340: steps=13,reward=-13
# Episode 1341: steps=15,reward=-15
# Episode 1342: steps=13,reward=-13
# Episode 1343: steps=17,reward=-17
# Episode 1344: steps=15,reward=-15
# Episode 1345: steps=13,reward=-13
# Episode 1346: steps=13,reward=-13
# Episode 1347: steps=23,reward=-23
# Episode 1348: steps=13,reward=-13
# Episode 1349: steps=15,reward=-15
# Episode 1350: steps=13,reward=-13
# Episode 1351: steps=13,reward=-13
# Episode 1352: steps=16,reward=-16
# Episode 1353: steps=22,reward=-220
# Episode 1354: steps=15,reward=-15
# Episode 1355: steps=15,reward=-15
# Episode 1356: steps=21,reward=-21
# Episode 1357: steps=19,reward=-118
# Episode 1358: steps=17,reward=-17
# Episode 1359: steps=29,reward=-227
# Episode 1360: steps=15,reward=-15
# Episode 1361: steps=13,reward=-13
# Episode 1362: steps=13,reward=-13
# Episode 1363: steps=36,reward=-135
# Episode 1364: steps=18,reward=-117
# Episode 1365: steps=13,reward=-13
# Episode 1366: steps=13,reward=-13
# Episode 1367: steps=27,reward=-126
# Episode 1368: steps=14,reward=-113
# Episode 1369: steps=13,reward=-13
# Episode 1370: steps=32,reward=-230
# Episode 1371: steps=18,reward=-18
# Episode 1372: steps=13,reward=-13
# Episode 1373: steps=13,reward=-13
# Episode 1374: steps=15,reward=-15
# Episode 1375: steps=14,reward=-14
# Episode 1376: steps=23,reward=-122
# Episode 1377: steps=13,reward=-13
# Episode 1378: steps=37,reward=-235
# Episode 1379: steps=13,reward=-13
# Episode 1380: steps=13,reward=-13
# Episode 1381: steps=13,reward=-13
# Episode 1382: steps=25,reward=-124
# Episode 1383: steps=17,reward=-17
# Episode 1384: steps=13,reward=-13
# Episode 1385: steps=27,reward=-126
# Episode 1386: steps=23,reward=-122
# Episode 1387: steps=15,reward=-15
# Episode 1388: steps=15,reward=-15
# Episode 1389: steps=13,reward=-13
# Episode 1390: steps=13,reward=-13
# Episode 1391: steps=13,reward=-13
# Episode 1392: steps=13,reward=-13
# Episode 1393: steps=15,reward=-15
# Episode 1394: steps=13,reward=-13
# Episode 1395: steps=15,reward=-15
# Episode 1396: steps=13,reward=-13
# Episode 1397: steps=13,reward=-13
# Episode 1398: steps=13,reward=-13
# Episode 1399: steps=13,reward=-13
# Episode 1400: steps=13,reward=-13
# Episode 1401: steps=25,reward=-124
# Episode 1402: steps=13,reward=-13
# Episode 1403: steps=13,reward=-13
# Episode 1404: steps=26,reward=-224
# Episode 1405: steps=15,reward=-15
# Episode 1406: steps=13,reward=-13
# Episode 1407: steps=13,reward=-13
# Episode 1408: steps=15,reward=-15
# Episode 1409: steps=17,reward=-215
# Episode 1410: steps=15,reward=-15
# Episode 1411: steps=13,reward=-13
# Episode 1412: steps=19,reward=-19
# Episode 1413: steps=13,reward=-13
# Episode 1414: steps=23,reward=-122
# Episode 1415: steps=14,reward=-14
# Episode 1416: steps=13,reward=-13
# Episode 1417: steps=15,reward=-15
# Episode 1418: steps=15,reward=-15
# Episode 1419: steps=26,reward=-125
# Episode 1420: steps=13,reward=-13
# Episode 1421: steps=13,reward=-13
# Episode 1422: steps=17,reward=-17
# Episode 1423: steps=14,reward=-113
# Episode 1424: steps=13,reward=-13
# Episode 1425: steps=34,reward=-232
# Episode 1426: steps=15,reward=-15
# Episode 1427: steps=34,reward=-232
# Episode 1428: steps=28,reward=-127
# Episode 1429: steps=13,reward=-13
# Episode 1430: steps=46,reward=-343
# Episode 1431: steps=15,reward=-15
# Episode 1432: steps=13,reward=-13
# ...
# Episode 9539: steps=22,reward=-220
# Episode 9540: steps=15,reward=-15
# Episode 9541: steps=14,reward=-14
# Episode 9542: steps=13,reward=-13
# Episode 9543: steps=25,reward=-124
# Episode 9544: steps=15,reward=-15
# Episode 9545: steps=14,reward=-14
# Episode 9546: steps=13,reward=-13
# Episode 9547: steps=17,reward=-17
# Episode 9548: steps=13,reward=-13
# Episode 9549: steps=15,reward=-15
# Episode 9550: steps=17,reward=-17
# Episode 9551: steps=13,reward=-13
# Episode 9552: steps=16,reward=-16
# Episode 9553: steps=13,reward=-13
# Episode 9554: steps=19,reward=-19
# Episode 9555: steps=13,reward=-13
# Episode 9556: steps=13,reward=-13
# Episode 9557: steps=13,reward=-13
# Episode 9558: steps=13,reward=-13
# Episode 9559: steps=13,reward=-13
# Episode 9560: steps=20,reward=-119
# Episode 9561: steps=15,reward=-15
# Episode 9562: steps=15,reward=-15
# Episode 9563: steps=15,reward=-15
# Episode 9564: steps=14,reward=-14
# Episode 9565: steps=13,reward=-13
# Episode 9566: steps=23,reward=-122
# Episode 9567: steps=15,reward=-15
# Episode 9568: steps=13,reward=-13
# Episode 9569: steps=19,reward=-118
# Episode 9570: steps=13,reward=-13
# Episode 9571: steps=27,reward=-126
# Episode 9572: steps=14,reward=-14
# Episode 9573: steps=15,reward=-15
# Episode 9574: steps=13,reward=-13
# Episode 9575: steps=13,reward=-13
# Episode 9576: steps=13,reward=-13
# Episode 9577: steps=13,reward=-13
# Episode 9578: steps=13,reward=-13
# Episode 9579: steps=13,reward=-13
# Episode 9580: steps=17,reward=-17
# Episode 9581: steps=15,reward=-15
# Episode 9582: steps=13,reward=-13
# Episode 9583: steps=13,reward=-13
# Episode 9584: steps=17,reward=-17
# Episode 9585: steps=14,reward=-14
# Episode 9586: steps=13,reward=-13
# Episode 9587: steps=13,reward=-13
# Episode 9588: steps=13,reward=-13
# Episode 9589: steps=15,reward=-15
# Episode 9590: steps=13,reward=-13
# Episode 9591: steps=26,reward=-125
# Episode 9592: steps=15,reward=-15
# Episode 9593: steps=13,reward=-13
# Episode 9594: steps=13,reward=-13
# Episode 9595: steps=13,reward=-13
# Episode 9596: steps=13,reward=-13
# Episode 9597: steps=13,reward=-13
# Episode 9598: steps=15,reward=-15
# Episode 9599: steps=14,reward=-14
# Episode 9600: steps=13,reward=-13
# Episode 9601: steps=17,reward=-17
# Episode 9602: steps=21,reward=-120
# Episode 9603: steps=18,reward=-18
# Episode 9604: steps=15,reward=-15
# Episode 9605: steps=13,reward=-13
# Episode 9606: steps=17,reward=-17
# Episode 9607: steps=15,reward=-15
# Episode 9608: steps=15,reward=-15
# Episode 9609: steps=13,reward=-13
# Episode 9610: steps=20,reward=-119
# Episode 9611: steps=13,reward=-13
# Episode 9612: steps=19,reward=-19
# Episode 9613: steps=25,reward=-124
# Episode 9614: steps=15,reward=-15
# Episode 9615: steps=13,reward=-13
# Episode 9616: steps=15,reward=-15
# Episode 9617: steps=31,reward=-229
# Episode 9618: steps=23,reward=-122
# Episode 9619: steps=16,reward=-16
# Episode 9620: steps=19,reward=-118
# Episode 9621: steps=13,reward=-13
# Episode 9622: steps=36,reward=-234
# Episode 9623: steps=13,reward=-13
# Episode 9624: steps=16,reward=-115
# Episode 9625: steps=14,reward=-14
# Episode 9626: steps=13,reward=-13
# Episode 9627: steps=17,reward=-17
# Episode 9628: steps=17,reward=-17
# Episode 9629: steps=20,reward=-119
# Episode 9630: steps=13,reward=-13
# Episode 9631: steps=17,reward=-17
# Episode 9632: steps=22,reward=-121
# Episode 9633: steps=15,reward=-15
# Episode 9634: steps=15,reward=-15
# Episode 9635: steps=13,reward=-13
# Episode 9636: steps=15,reward=-15
# Episode 9637: steps=15,reward=-213
# Episode 9638: steps=13,reward=-13
# Episode 9639: steps=16,reward=-16
# Episode 9640: steps=17,reward=-17
# Episode 9641: steps=13,reward=-13
# Episode 9642: steps=23,reward=-122
# Episode 9643: steps=17,reward=-116
# Episode 9644: steps=26,reward=-224
# Episode 9645: steps=15,reward=-213
# Episode 9646: steps=13,reward=-13
# Episode 9647: steps=17,reward=-116
# Episode 9648: steps=18,reward=-117
# Episode 9649: steps=15,reward=-15
# Episode 9650: steps=16,reward=-115
# Episode 9651: steps=13,reward=-13
# Episode 9652: steps=13,reward=-13
# Episode 9653: steps=13,reward=-13
# Episode 9654: steps=22,reward=-121
# Episode 9655: steps=13,reward=-13
# Episode 9656: steps=15,reward=-15
# Episode 9657: steps=35,reward=-233
# Episode 9658: steps=22,reward=-121
# Episode 9659: steps=13,reward=-13
# Episode 9660: steps=13,reward=-13
# Episode 9661: steps=15,reward=-15
# Episode 9662: steps=13,reward=-13
# Episode 9663: steps=15,reward=-15
# Episode 9664: steps=15,reward=-15
# Episode 9665: steps=16,reward=-16
# Episode 9666: steps=13,reward=-13
# Episode 9667: steps=21,reward=-120
# Episode 9668: steps=17,reward=-17
# Episode 9669: steps=13,reward=-13
# Episode 9670: steps=14,reward=-14
# Episode 9671: steps=26,reward=-224
# Episode 9672: steps=13,reward=-13
# Episode 9673: steps=13,reward=-13
# Episode 9674: steps=14,reward=-113
# Episode 9675: steps=13,reward=-13
# Episode 9676: steps=13,reward=-13
# Episode 9677: steps=15,reward=-15
# Episode 9678: steps=13,reward=-13
# Episode 9679: steps=13,reward=-13
# Episode 9680: steps=13,reward=-13
# Episode 9681: steps=15,reward=-15
# Episode 9682: steps=13,reward=-13
# Episode 9683: steps=24,reward=-123
# Episode 9684: steps=13,reward=-13
# Episode 9685: steps=13,reward=-13
# Episode 9686: steps=13,reward=-13
# Episode 9687: steps=15,reward=-15
# Episode 9688: steps=14,reward=-113
# Episode 9689: steps=13,reward=-13
# Episode 9690: steps=13,reward=-13
# Episode 9691: steps=22,reward=-121
# Episode 9692: steps=30,reward=-129
# Episode 9693: steps=15,reward=-15
# Episode 9694: steps=13,reward=-13
# Episode 9695: steps=17,reward=-116
# Episode 9696: steps=16,reward=-16
# Episode 9697: steps=24,reward=-123
# Episode 9698: steps=34,reward=-232
# Episode 9699: steps=13,reward=-13
# Episode 9700: steps=26,reward=-125
# Episode 9701: steps=20,reward=-119
# Episode 9702: steps=14,reward=-14
# Episode 9703: steps=13,reward=-13
# Episode 9704: steps=13,reward=-13
# Episode 9705: steps=17,reward=-17
# Episode 9706: steps=22,reward=-22
# Episode 9707: steps=13,reward=-13
# Episode 9708: steps=13,reward=-13
# Episode 9709: steps=15,reward=-15
# Episode 9710: steps=14,reward=-14
# Episode 9711: steps=13,reward=-13
# Episode 9712: steps=14,reward=-14
# Episode 9713: steps=15,reward=-15
# Episode 9714: steps=13,reward=-13
# Episode 9715: steps=15,reward=-15
# Episode 9716: steps=14,reward=-14
# Episode 9717: steps=13,reward=-13
# Episode 9718: steps=15,reward=-15
# Episode 9719: steps=13,reward=-13
# Episode 9720: steps=13,reward=-13
# Episode 9721: steps=13,reward=-13
# Episode 9722: steps=13,reward=-13
# Episode 9723: steps=15,reward=-15
# Episode 9724: steps=13,reward=-13
# Episode 9725: steps=15,reward=-15
# Episode 9726: steps=21,reward=-21
# Episode 9727: steps=26,reward=-125
# Episode 9728: steps=17,reward=-17
# Episode 9729: steps=13,reward=-13
# Episode 9730: steps=13,reward=-13
# Episode 9731: steps=13,reward=-13
# Episode 9732: steps=15,reward=-15
# Episode 9733: steps=19,reward=-19
# Episode 9734: steps=15,reward=-15
# Episode 9735: steps=13,reward=-13
# Episode 9736: steps=25,reward=-124
# Episode 9737: steps=13,reward=-13
# Episode 9738: steps=15,reward=-15
# Episode 9739: steps=13,reward=-13
# Episode 9740: steps=17,reward=-17
# Episode 9741: steps=13,reward=-13
# Episode 9742: steps=16,reward=-16
# Episode 9743: steps=14,reward=-14
# Episode 9744: steps=21,reward=-120
# Episode 9745: steps=17,reward=-17
# Episode 9746: steps=19,reward=-19
# Episode 9747: steps=13,reward=-13
# Episode 9748: steps=15,reward=-15
# Episode 9749: steps=20,reward=-20
# Episode 9750: steps=15,reward=-15
# Episode 9751: steps=13,reward=-13
# Episode 9752: steps=17,reward=-17
# Episode 9753: steps=15,reward=-15
# Episode 9754: steps=13,reward=-13
# Episode 9755: steps=15,reward=-15
# Episode 9756: steps=13,reward=-13
# Episode 9757: steps=15,reward=-15
# Episode 9758: steps=15,reward=-15
# Episode 9759: steps=13,reward=-13
# Episode 9760: steps=15,reward=-15
# Episode 9761: steps=13,reward=-13
# Episode 9762: steps=28,reward=-226
# Episode 9763: steps=13,reward=-13
# Episode 9764: steps=15,reward=-15
# Episode 9765: steps=13,reward=-13
# Episode 9766: steps=30,reward=-129
# Episode 9767: steps=23,reward=-221
# Episode 9768: steps=13,reward=-13
# Episode 9769: steps=15,reward=-15
# Episode 9770: steps=15,reward=-15
# Episode 9771: steps=13,reward=-13
# Episode 9772: steps=13,reward=-13
# Episode 9773: steps=13,reward=-13
# Episode 9774: steps=37,reward=-334
# Episode 9775: steps=17,reward=-17
# Episode 9776: steps=15,reward=-15
# Episode 9777: steps=15,reward=-15
# Episode 9778: steps=13,reward=-13
# Episode 9779: steps=13,reward=-13
# Episode 9780: steps=14,reward=-113
# Episode 9781: steps=13,reward=-13
# Episode 9782: steps=15,reward=-15
# Episode 9783: steps=15,reward=-114
# Episode 9784: steps=13,reward=-13
# Episode 9785: steps=13,reward=-13
# Episode 9786: steps=34,reward=-331
# Episode 9787: steps=15,reward=-15
# Episode 9788: steps=13,reward=-13
# Episode 9789: steps=24,reward=-123
# Episode 9790: steps=13,reward=-13
# Episode 9791: steps=15,reward=-15
# Episode 9792: steps=15,reward=-15
# Episode 9793: steps=17,reward=-17
# Episode 9794: steps=15,reward=-15
# Episode 9795: steps=13,reward=-13
# Episode 9796: steps=14,reward=-14
# Episode 9797: steps=13,reward=-13
# Episode 9798: steps=23,reward=-221
# Episode 9799: steps=15,reward=-15
# Episode 9800: steps=31,reward=-229
# Episode 9801: steps=16,reward=-16
# Episode 9802: steps=13,reward=-13
# Episode 9803: steps=13,reward=-13
# Episode 9804: steps=18,reward=-117
# Episode 9805: steps=15,reward=-15
# Episode 9806: steps=34,reward=-232
# Episode 9807: steps=40,reward=-238
# Episode 9808: steps=13,reward=-13
# Episode 9809: steps=17,reward=-17
# Episode 9810: steps=13,reward=-13
# Episode 9811: steps=13,reward=-13
# Episode 9812: steps=13,reward=-13
# Episode 9813: steps=13,reward=-13
# Episode 9814: steps=13,reward=-13
# Episode 9815: steps=17,reward=-17
# Episode 9816: steps=15,reward=-15
# Episode 9817: steps=30,reward=-228
# Episode 9818: steps=13,reward=-13
# Episode 9819: steps=17,reward=-17
# Episode 9820: steps=13,reward=-13
# Episode 9821: steps=20,reward=-20
# Episode 9822: steps=13,reward=-13
# Episode 9823: steps=27,reward=-126
# Episode 9824: steps=14,reward=-14
# Episode 9825: steps=20,reward=-20
# Episode 9826: steps=13,reward=-13
# Episode 9827: steps=19,reward=-19
# Episode 9828: steps=15,reward=-15
# Episode 9829: steps=22,reward=-121
# Episode 9830: steps=13,reward=-13
# Episode 9831: steps=15,reward=-15
# Episode 9832: steps=19,reward=-19
# Episode 9833: steps=15,reward=-15
# Episode 9834: steps=30,reward=-129
# Episode 9835: steps=15,reward=-15
# Episode 9836: steps=20,reward=-119
# Episode 9837: steps=19,reward=-118
# Episode 9838: steps=13,reward=-13
# Episode 9839: steps=18,reward=-117
# Episode 9840: steps=30,reward=-129
# Episode 9841: steps=13,reward=-13
# Episode 9842: steps=15,reward=-15
# Episode 9843: steps=13,reward=-13
# Episode 9844: steps=13,reward=-13
# Episode 9845: steps=13,reward=-13
# Episode 9846: steps=13,reward=-13
# Episode 9847: steps=15,reward=-15
# Episode 9848: steps=13,reward=-13
# Episode 9849: steps=19,reward=-19
# Episode 9850: steps=15,reward=-15
# Episode 9851: steps=13,reward=-13
# Episode 9852: steps=13,reward=-13
# Episode 9853: steps=17,reward=-116
# Episode 9854: steps=15,reward=-15
# Episode 9855: steps=15,reward=-15
# Episode 9856: steps=28,reward=-127
# Episode 9857: steps=13,reward=-13
# Episode 9858: steps=15,reward=-15
# Episode 9859: steps=13,reward=-13
# Episode 9860: steps=15,reward=-15
# Episode 9861: steps=13,reward=-13
# Episode 9862: steps=25,reward=-25
# Episode 9863: steps=19,reward=-118
# Episode 9864: steps=13,reward=-13
# Episode 9865: steps=13,reward=-13
# Episode 9866: steps=28,reward=-127
# Episode 9867: steps=13,reward=-13
# Episode 9868: steps=15,reward=-15
# Episode 9869: steps=13,reward=-13
# Episode 9870: steps=20,reward=-119
# Episode 9871: steps=15,reward=-15
# Episode 9872: steps=15,reward=-15
# Episode 9873: steps=34,reward=-232
# Episode 9874: steps=13,reward=-13
# Episode 9875: steps=15,reward=-15
# Episode 9876: steps=14,reward=-14
# Episode 9877: steps=15,reward=-15
# Episode 9878: steps=13,reward=-13
# Episode 9879: steps=15,reward=-15
# Episode 9880: steps=13,reward=-13
# Episode 9881: steps=13,reward=-13
# Episode 9882: steps=15,reward=-15
# Episode 9883: steps=14,reward=-14
# Episode 9884: steps=15,reward=-15
# Episode 9885: steps=25,reward=-124
# Episode 9886: steps=15,reward=-15
# Episode 9887: steps=13,reward=-13
# Episode 9888: steps=17,reward=-17
# Episode 9889: steps=15,reward=-15
# Episode 9890: steps=15,reward=-114
# Episode 9891: steps=20,reward=-119
# Episode 9892: steps=13,reward=-13
# Episode 9893: steps=13,reward=-13
# Episode 9894: steps=13,reward=-13
# Episode 9895: steps=13,reward=-13
# Episode 9896: steps=19,reward=-19
# Episode 9897: steps=13,reward=-13
# Episode 9898: steps=25,reward=-124
# Episode 9899: steps=26,reward=-125
# Episode 9900: steps=14,reward=-14
# Episode 9901: steps=40,reward=-238
# Episode 9902: steps=13,reward=-13
# Episode 9903: steps=13,reward=-13
# Episode 9904: steps=13,reward=-13
# Episode 9905: steps=17,reward=-17
# Episode 9906: steps=15,reward=-15
# Episode 9907: steps=13,reward=-13
# Episode 9908: steps=20,reward=-119
# Episode 9909: steps=13,reward=-13
# Episode 9910: steps=15,reward=-15
# Episode 9911: steps=15,reward=-15
# Episode 9912: steps=13,reward=-13
# Episode 9913: steps=13,reward=-13
# Episode 9914: steps=17,reward=-17
# Episode 9915: steps=31,reward=-229
# Episode 9916: steps=13,reward=-13
# Episode 9917: steps=15,reward=-15
# Episode 9918: steps=13,reward=-13
# Episode 9919: steps=27,reward=-126
# Episode 9920: steps=13,reward=-13
# Episode 9921: steps=13,reward=-13
# Episode 9922: steps=13,reward=-13
# Episode 9923: steps=13,reward=-13
# Episode 9924: steps=21,reward=-120
# Episode 9925: steps=15,reward=-15
# Episode 9926: steps=23,reward=-122
# Episode 9927: steps=17,reward=-17
# Episode 9928: steps=13,reward=-13
# Episode 9929: steps=15,reward=-15
# Episode 9930: steps=15,reward=-15
# Episode 9931: steps=27,reward=-225
# Episode 9932: steps=13,reward=-13
# Episode 9933: steps=13,reward=-13
# Episode 9934: steps=15,reward=-15
# Episode 9935: steps=13,reward=-13
# Episode 9936: steps=13,reward=-13
# Episode 9937: steps=17,reward=-17
# Episode 9938: steps=13,reward=-13
# Episode 9939: steps=30,reward=-228
# Episode 9940: steps=13,reward=-13
# Episode 9941: steps=13,reward=-13
# Episode 9942: steps=20,reward=-119
# Episode 9943: steps=13,reward=-13
# Episode 9944: steps=13,reward=-13
# Episode 9945: steps=13,reward=-13
# Episode 9946: steps=22,reward=-121
# Episode 9947: steps=17,reward=-17
# Episode 9948: steps=15,reward=-15
# Episode 9949: steps=13,reward=-13
# Episode 9950: steps=15,reward=-15
# Episode 9951: steps=13,reward=-13
# Episode 9952: steps=15,reward=-15
# Episode 9953: steps=13,reward=-13
# Episode 9954: steps=13,reward=-13
# Episode 9955: steps=13,reward=-13
# Episode 9956: steps=23,reward=-122
# Episode 9957: steps=13,reward=-13
# Episode 9958: steps=13,reward=-13
# Episode 9959: steps=15,reward=-15
# Episode 9960: steps=13,reward=-13
# Episode 9961: steps=14,reward=-14
# Episode 9962: steps=13,reward=-13
# Episode 9963: steps=14,reward=-14
# Episode 9964: steps=18,reward=-18
# Episode 9965: steps=13,reward=-13
# Episode 9966: steps=13,reward=-13
# Episode 9967: steps=19,reward=-19
# Episode 9968: steps=13,reward=-13
# Episode 9969: steps=13,reward=-13
# Episode 9970: steps=13,reward=-13
# Episode 9971: steps=13,reward=-13
# Episode 9972: steps=25,reward=-124
# Episode 9973: steps=13,reward=-13
# Episode 9974: steps=13,reward=-13
# Episode 9975: steps=13,reward=-13
# Episode 9976: steps=15,reward=-15
# Episode 9977: steps=13,reward=-13
# Episode 9978: steps=13,reward=-13
# Episode 9979: steps=13,reward=-13
# Episode 9980: steps=13,reward=-13
# Episode 9981: steps=13,reward=-13
# Episode 9982: steps=15,reward=-15
# Episode 9983: steps=13,reward=-13
# Episode 9984: steps=15,reward=-15
# Episode 9985: steps=13,reward=-13
# Episode 9986: steps=14,reward=-14
# Episode 9987: steps=13,reward=-13
# Episode 9988: steps=13,reward=-13
# Episode 9989: steps=15,reward=-15
# Episode 9990: steps=15,reward=-15
# Episode 9991: steps=13,reward=-13
# Episode 9992: steps=14,reward=-14
# Episode 9993: steps=22,reward=-121
# Episode 9994: steps=14,reward=-113
# Episode 9995: steps=13,reward=-13
# Episode 9996: steps=13,reward=-13
# Episode 9997: steps=13,reward=-13
# Episode 9998: steps=18,reward=-117
# Episode 9999: steps=13,reward=-13
# teset 0 reward = -13
# teset 1 reward = -13
# teset 2 reward = -13
# teset 3 reward = -13
# teset 4 reward = -13
# teset 5 reward = -13
# teset 6 reward = -13
# teset 7 reward = -13
# teset 8 reward = -13
# teset 9 reward = -13
